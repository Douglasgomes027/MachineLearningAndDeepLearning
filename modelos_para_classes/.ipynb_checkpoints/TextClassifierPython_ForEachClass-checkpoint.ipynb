# %%
import numpy as np
import pandas as pd
import re

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
def file_parser(file):
    for line in file:
        line = re.sub("\n", "", line)
        yield re.split(r',', line, 2)

parser = file_parser(open('Teste_Classificacao_Out_01-15CLASSE_GENERO_PRODUTO.csv', encoding="ISO-8859-1"))
columns = next(parser)


df = pd.DataFrame(parser, columns=columns)
df_test=df

# %%
df.columns
# Out:
# Index(['CLASSE', 'GENERO', 'PRODUTO'], dtype='object')

# %%
df.GENERO.unique()
# Out:
# array(['ADUBO', 'FERTILIZANTE', 'ACESSORIO PARA ARMA', 'ALBUM', 'CARTOES',
#        'EMBALAGEM PARA PRESENTE', 'FAIXAS', 'FOLHETO', 'JORNAL', 'LIVRO',
#        'MATERIAL PARA ESCRITORIO E ESCOLAR', 'PAPEL', 'REVISTA',
#        'PRODUTO PARA FESTA', 'ACESSORIO DE VIAGEM',
#        'PARTE E ACESSORIO DE RELOJOARIA', 'RELOGIO', 'AGUA', 'CAJUINA',
#        'CERVEJA', 'ENERGETICO', 'HIDROTONICO', 'ISOTONICO', 'REFRIGERANTE',
#        'AGUARDENTE', 'APERITIVO', 'CHAMPAGNE', 'ESPUMANTE', 'LICOR', 'RUM',
#        'SAQUE', 'TEQUILA', 'VERMOUTH', 'VINHO', 'VODKA', 'WHISKY',
#        'BRINQUEDO', 'GAME', 'ACESSORIO PARA CALCADO', 'BOTA', 'CHINELO',
#        'CHUTEIRA', 'SANDALIA', 'SAPATILHA', 'SAPATO', 'TENIS',
#        'ACESSORIO DE VESTUARIO', 'AVIAMENTO', 'MODA PRAIA', 'PECA INTIMA',
#        'VESTUARIO FEMININO', 'VESTUARIO INFANTIL', 'VESTUARIO MASCULINO',
#        'ESTRUTURA FLUTUANTE', 'ACESSORIO E EQUIPAMENTO PARA ESPORTE',
#        'PRODUTO FARMACEUTICO', 'ABRASIVO', 'FERRAGEM',
#        'MAQUINA E EQUIPAMENTO', 'PRODUTO PARA ORGANIZACAO',
#        'PRODUTO PARA SOLDA', 'TIPO DE FERRAMENTA', 'TIPO DE GRAO',
#        'TIPO DE SEMENTE', 'ACESSORIO MUSICAL', 'INSTRUMENTO DE CORDA',
#        'INSTRUMENTO DE PERCUSSAO', 'TIPO DE MADEIRA', 'PRODUTO DE HIGIENE',
#        'PRODUTO DE LIMPEZA', 'PRODUTO PARA CONSERVACAO',
#        'UTENSILIO DE LIMPEZA', 'SUCATA', 'GENERICO',
#        'MEDICAMENTO NAO CLASSIFICADO', 'OUTROS MEDICAMENTOS', 'REFERENCIA',
#        'SIMILAR', 'ALUMINIO', 'PECAS E ACESSORIOS PARA MOVEIS',
#        'TIPO DE MOVEIS', 'ARTEFATO DE JOALHERIA E SUAS PARTES',
#        'BIJUTERIA', 'PRODUTO DE FLORICULTURA', 'TIPO DE PLANTA',
#        'ARTIGO PIROTECNICO', 'TIPO DE FOSFORO', 'ACUCAR', 'ADOCANTE',
#        'ALIMENTO CONDIMENTADO', 'ALIMENTO EM CONSERVA', 'ALIMENTO PRONTO',
#        'ARROZ', 'BISCOITO', 'BOMBONIERE', 'CAFE', 'CARNE BOVINA',
#        'CARNE DE AVE ', 'CARNE DE CRUSTACEO', 'CARNE DE PEIXE',
#        'CARNE OVINA', 'CARNE SUINA', 'CASCA DE FRUTA', 'CEREAL', 'CEVADA',
#        'CHA', 'DOCE E SOBREMESA', 'ESPECIARIA', 'FARELO',
#        'FARINHA E AMIDO', 'FEIJAO', 'FRUTA', 'LACTICINIO', 'LEITE',
#        'MACARRAO', 'MASSA PRONTA', 'MEL', 'MISTURA PRONTA', 'OLEO',
#        'OVO DE AVE', 'PAO', 'PREPARACAO DE CARNE', 'PREPARACAO DE FRUTA',
#        'PRODUTO DE CONFEITARIA', 'PROTEINA DE SOJA', 'SUCO', 'TEMPERO',
#        'TOUCINHO E GORDURA SUINA E DE AVE', 'VERDURA E LEGUME',
#        'ACESSORIO PARA BELEZA', 'COSMETICOS', 'MAOS', 'OLHOS',
#        'PERFUMARIA', 'PES', 'ROSTO', 'UNHAS', 'ACESSORIO DE INFORMATICA',
#        'INFORMATICA', 'ELETRODOMESTICO', 'ACESSORIO ELETRONICO', 'ALARME',
#        'ELETRONICO', 'ELETROPORTATEIS', 'EROTICO', 'EXCLUIDOS',
#        'EQUIPAMENTO HOSPITALAR', 'ODONTOLOGICO', 'ORTOPEDIA',
#        'PRODUTO HOSPITALAR', 'ACESSORIO PARA OTICA', 'PRODUTO OTICO',
#        'MATERIAL PARA ARTESANATO', 'ACESSORIO PARA BEBE',
#        'UTENSILIO PARA BEBE', 'VESTUARIO PARA BEBE', 'MATERIAL ELETRICO',
#        'MATERIAL PARA AGROPECUARIA', 'MATERIAL PARA CONSTRUCAO',
#        'PRODUTO PARA SEGURANCA', 'CAMERA E FILMADORA', 'COMBUSTIVEL',
#        'TIPO DE PESTICIDA', 'TIPO DE PRODUTO', 'ACESSORIOS RELIGIOSOS',
#        'ALIMENTO PARA ANIMAL', 'PRODUTO PARA ANIMAL', 'GRANITO', 'MARMORE',
#        'PEDRA CARIRI', 'PEDRA PORTUGUESA', 'FORMAS DE TABACO',
#        'TIPO DE TABACO', 'TINTA PARA TECIDO', 'TIPO DE TECIDO',
#        'ACESSORIO PARA CELULAR', 'ACESSORIO PARA TELEFONE FIXO', 'CELULAR',
#        'FAX E MINI CENTRAL', 'RADIO DE COMUNICACAO', 'TELEFONE FIXO',
#        'ARTIGO PARA DECORACAO', 'CAMA MESA E BANHO', 'PRODUTO DESCARTAVEL',
#        'UTENSILIO PARA O LAR', 'ACESSORIO PARA VEICULO', 'CARROCERIA',
#        'MOTOR', 'PARTE E PECA PARA VEICULO', 'SISTEMA DE ALIMENTACAO',
#        'SISTEMA DE AREFECIEMENTO', 'SISTEMA DE DIRECAO',
#        'SISTEMA DE ELETRICO', 'SISTEMA DE ESCAPAMENTO',
#        'SISTEMA DE FREIOS', 'SISTEMA DE SUSPENCAO',
#        'SISTEMA DE TRANSMISSAO', 'VEICULO TERRESTRE', 'TIPO DE VELA',
#        'TIPO DE VIDRO'], dtype=object)

# %%
y = df_test['GENERO']
X = df_test['PRODUTO'].tolist()
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
X
# Out:
# ['ESTERCO TL',
#  'HUMUS D MINHOCA GNUMUS 3KG',
#  'FERTIL 06-24-12 50KG YARA SC',
#  'AMIORGAN (50 KG) SC',
#  'TOP-PHOS 328 EN - 50KG KG',
#  'CALCARIO AGRICOLA - 40 KG TON',
#  'DRIPSOL KCL STANDARD SC 25KG',
#  'CAPA PARA ALMOFADA 79904',
#  'CAPA ESPINGARDA ALMOFADA CAMUFLADA',
#  'CHUMBINHO ESPING.DIABOLO5.1/2 C125 CX',
#  'CHUMBINHO ESPING.DIABO 4.1/2 C250 CX',
#  '"CHUMBINHO ESPING 5,5MM DIABOLO C/125 LOBO"',
#  'E MENINO! LIVRO DE RECORDACOES',
#  'PORTA CRACHA ACP HORIZONTAL C- 7 C/50UN',
#  'CRACHA HORIZONTAL 07X10 PREND.METAL',
#  'RETANGULAR ALTA 26X18X10CM - 7898198010207',
#  'RETANGULAR ALTA 20X14X9CM - 7898198010191',
#  '"RETANGULAR ALTA 37,5X27,5X14CM - 7898198010214"',
#  'LACO PRESENTE PULL FLOWER RIBBON PT/10 R1044 PT',
#  'SACO PRESENTE 10X14 INCOLOR C/50 UN PC',
#  'SACO CROMUS PEROL 45X59 PT/25 PT',
#  'SACO CROMUS P/CESTA SORT. 52X70 C/25UN',
#  'SACO CROMUS SORTIDO 10X14 C/50UN',
#  'SACO CROMUS PEROL 20X29 PT C/50',
#  'SACOLA DE PRESENTE P MAES 2014 TAG PC',
#  'SACOLA G MASC NAMORADOS 2014 PC',
#  'SACOLA PRESENTE',
#  'FAIXA REGINA FELIZ ANIVERSARIO',
#  '(K:10072911)ROTEIRO PARA SESSSDE BELEZA MARY KAY',
#  'DOMINGO DAS CRIANCAS',
#  '(K:10072911)FOLHETO COMPLEMENTE A SUA BELEZA (30UN)',
#  'DOMINGO O REMESSA 14',
#  'COMISSÃ\x83O SOBRE VEICULAÃ\x87Ã\x83O JORNAL DIARIO DO NORDESTE',
#  '"POVO, O DOMINGO"',
#  'JORNAL O POVO SABADO',
#  'APT F1 CADERNO5- 1 ANO-FSC MISTO-GEO- MEAL',
#  'AGENTE ADMINISTRATIVO POLICIA FEDERAL',
#  'POLICIA FEDERAL - AGENTE ADMINISTRATIVO',
#  'APT F1 CADERNO5- 2 ANO-FSC MISTO-GEO- MEAL',
#  'DICIONARIO ESCOLAR DA LINGUA PORTUGUESA 9788504014129',
#  'MINI DICIONARIO AURELIO DA LINGUA PORTUGUESA 8 EX',
#  'MINI DICIONARIO DA LINGUA PORTUGUESA',
#  'MICHAELIS DICIONARIO ESCOLAR LINGUA PORTUGUESA',
#  'MINIDICIONARIO ING-POR/POR-ING-S.BUENO-CM-2007',
#  'DICIONARIO OXFORD ESCOLAR PARA ESTUDANTES BRASIL EX',
#  'MICHAELIS DICIONARIO ESCOLAR INGLES',
#  'DICIONARIO SANTILLANA PARA ESTUDANTES',
#  'MICHAELIS DICIONARIO ESCOLAR ESPANHOL',
#  '365 DIAS EXTRAORDINARIOS',
#  'O DIARIO DE ANNE FRANK EDICAO DEFINITIVA EX',
#  'EU SOU MALALA',
#  'DEMI LOVATO 365 DIAS DO ANO 1A ED PC',
#  '"MANIFESTO COMUNISTA,O-44 - MARTIN CLARET"',
#  'DIARIO DE ANNE FRANK',
#  'DANEM SE OS NORMAIS',
#  '"ETICA PROTESTANTE E O ESP.CAPITALISMO,A-49 - MARTIN CLARET"',
#  'FORA DE SERIE- OUTLIERS',
#  '"PRECO MUITO ALTO, UM"',
#  'FORA DE SERIE (OUTLIERS)',
#  'LEVIATA-SERIE OURO 01 - MARTIN CLARET',
#  '"CAVALEIRO PRESO NA ARMADURA, O"',
#  'PATINHO FEIO O',
#  'UM SORRISO OU DOIS PARA MULHERES QUE QUEREM MAIS EX',
#  'CLASSICOS INFANTIS - O PATINHO FEIO',
#  'UM SORRISO OU DOIS',
#  'ECHO A1 CAHIER PERSONNEL DAPPRENTISSAGE',
#  'ECHO A1 LIVRE DE LELEVE',
#  'KIDS WEB 3 ED2',
#  'SEMIDEUSES E MONSTROS',
#  '"LIVRO DOS NEGOCIOS, O"',
#  '"TRIADE DO TEMPO, A"',
#  'SONHO GRANDE EX',
#  'DESCUBRA SEUS PONTOS FORTES',
#  'ANTIFRAGIL COISAS QUE SE BENEFICIAM COM O CAOS',
#  '"ARTE DA GUERRA,A-54 - MARTIN CLARET"',
#  'GERENCIAMENTO DA ROTINA DO TRABALHO DO DIA A DIA',
#  'O MONGE E O EXECUTIVO UMA HISTORIA SOBRE A ESSEN EX',
#  'DE VOLTA AO MOSTEIRO O MONGE E O EXECUTIVO FALAM EX',
#  'A ARTE DA GUERRA OS TREZE CAPITULOS ORIGINAIS EX',
#  'SEGREDOS DO MERCADO DE ACOES',
#  'A TRIADE DO TEMPO PC',
#  '"LIVRO - MONGE E O EXECUTIVO, O PC"',
#  'LIVRO O MONGE E O EXECUTIVO PEC',
#  'FACA ACONTECER',
#  'DESTRUA ESTE DIARIO (CAPA ORIGINAL)',
#  'HAMLET-39 - MARTIN CLARET',
#  'DESTRUA ESTE DIARIO 1A ED PC',
#  'CRIANCAS FRANCESAS NAO FAZEM MANHA',
#  'LIVRO PONTO 100F 4 ASS GRAFSET 10209',
#  'LIVRO SAUDE',
#  'LIVRO GRAFSET PONTO 4 ASS 100FLS 10209',
#  'LIVRO PONTO 04 ASS. GRAFSET OF C/100 FLS',
#  'LIVRO SAUDE TOTAL 1',
#  'DESPERTE SEU GIGANTE INTERIOR',
#  'O LIVRO DO BEM COISAS PARA VOCE FAZER E DEIXAR O EX',
#  'LIVRO NUNCA DESISTA DOS SEUS SONHOS PEC',
#  'GERACAO DE VALOR COMPARTILHANDO INSPIRACAO EX',
#  'MINUTOS DE SABEDORIA 1 - CAPA PLASTICA',
#  'LIVRO DIGITAL FISIOTERAPIA HOSPITALAR',
#  '"ORIGEM DAS ESPECIES,A-EDICAO ESPECIAL - MARTIN CLARET"',
#  'CJ-PORTA ABERTA-CIENCIAS-5OANO',
#  'O LIVRO DA POLITICA EX',
#  'CJ-PORTA ABERTA-CIENCIAS-2OANO',
#  '"OLHO DA RUA, O"',
#  'DIREITOS HUMANOS FUNDAMENTAIS',
#  'COMO PASSAR NA OAB 1 FASE 5.000 QUESTOES COME EX',
#  'DIREITO TRIBUTARIO ESQUEMATIZADO',
#  'DIREITO ELEITORAL',
#  '"LUTA PELO DIREITO,A-47 - MARTIN CLARET"',
#  'DIREITO CONSTITUCIONAL ESQUEMATIZADO',
#  'DO ESPIRITO DAS LEIS-SERIE OURO 09 - MARTIN CLARET',
#  'MANUAL DE DIREITO PREVIDENCIARIO SERIE CONCURSOS EX',
#  'O LIVRO DA ECONOMIA AS GRANDES IDEIAS DE TODOS O EX',
#  'ARTE DE PROJETAR EM ARQUITETURA 18 ED. 2013 EX',
#  'APOSTILA EXCEL 2010',
#  '"LIVRO DA MITOLOGIA,O - EDICAO ESPECIAL-02 - MARTIN CLARET"',
#  'LIVRO DOS HOMENS',
#  'PALAVRAS CRUZADAS. MEDIO',
#  '1001 VIDEOGAMES PARA JOGAR ANTES DE MORRER EX',
#  '"LIVRO - GUIA DO MOCHILEIRO DAS GALAXIAS, O PC"',
#  'LIVRO - PRATICAMENTE INOFENSIVA - VOL. 5 - COLECAO GUIA DOS MOCHILEIROS DAS GALAXIAS PC',
#  'BELA COZINHA AS RECEITAS',
#  'LIVRO ASSADOS E GRELHADOS LIGHT',
#  '"POLITICA,A-61 - MARTIN CLARET"',
#  '"UTOPIA,A-40 - MARTIN CLARET"',
#  '"MAQUIAVEL, O PODER-202 - MARTIN CLARET"',
#  'LIVRO MANUAL DO LIDER CPS',
#  '"1889 COMO UM IMPERADOR CANSADO, UM MARECHAL VAI EX"',
#  '"IDEIAS CONSERVADORAS, AS"',
#  '"CIDADE ANTIGA,A-SERIE OURO 02 - MARTIN CLARET"',
#  'CIVILIZACAO',
#  'GUIA POLITICAMENTE INCORRETO DA HISTORIA DO MUNDO',
#  'HISTORIA MODERNA',
#  'CEM ANOS DE SOLIDAO',
#  'COMO DIZER TUDO COMO ESCREVER TUDO EM FRANCES - 1A ED PC',
#  'LIVRO 05 WISE UP TEENS KT',
#  'LIVRO 04 WISE UP TEENS KT',
#  'LIVRO 02 WISE UP TEENS KT',
#  'LIVRO 08 WISE UP TEENS KT',
#  'LIVRO 01 WISE UP TEENS KT',
#  'ABAIXO AS VERDADES SAGRADAS',
#  'A GRAMATICA PARA CONCURSOS PUBLICOS SERIE PROVAS EX',
#  'LIVRO 06 WISE UP TEENS KT',
#  'LIVRO 03 WISE UP TEENS KT',
#  'LIVRO EF 2O ANO - INGLES',
#  'LIVRO SPREADING WINGS (M)',
#  'LIVRO 07 WISE UP TEENS KT',
#  'LIVRO EF 1O ANO - INGLES',
#  'ENGLISH IN FORMATION-8OA -UPGRADED EDITION-CO-MERC',
#  'LIVRO 09 WISE UP TEENS KT',
#  '"MISERAVEIS, OS (VOL. II)-SERIE OURO 54 - MARTIN CLARET"',
#  '"LIVRO - FILHOS DE HURIN, OS PC"',
#  '"MORENINHA,A-9 - MARTIN CLARET"',
#  'CARTAS DE AMOR AOS MORTOS EX',
#  '"PRINCIPE,O-2 - MARTIN CLARET"',
#  'ULTIMO ADEUS DE SHERLOCK HOLMES-133 - MARTIN CLARET',
#  'DOS DELITOS E DAS PENAS-48 - MARTIN CLARET',
#  'MAR DE ROSAS',
#  'A ILHA EX',
#  'LV P TOP FLOR ULTRA QS 6X2L CX',
#  'FABULAS-ESOPO-182 - MARTIN CLARET',
#  'PEDAGOGIA DA AUTONOMIA',
#  '"SERTOES,OS-SERIE OURO 05 - MARTIN CLARET"',
#  'LIVRO ANJOS E DEMONIOS PEC',
#  'FRANKENSTEIN / MEDICO E O MONSTRO / DRACULA - MARTIN CLARET',
#  'LIVRO - FORTALEZA DIGITAL PC',
#  'LIVRO - RESTAURANTE DO FIM DO UNIVERSO - COLECAO GUIA DOS MOCHILEIROS DAS GALAXIAS PC',
#  'ASSIM FALOU ZARATUSTRA-EDICAO ESPECIAL - MARTIN CLARET',
#  'O MINIMO QUE VOCE PRECISA SABER PARA NAO SER UM ID EX',
#  '"AVENTURAS DE SHERLOCK HOLMES,AS-101 - MARTIN CLARET"',
#  '"MELHORES CONTOS,OS-"',
#  '"CAO DOS BASKERVILLES,O-64 - MARTIN CLARET"',
#  'PEDAGOGIA DO OPRIMIDO',
#  '"CAPITAL NO SECULO XXI, O"',
#  'LV P MIRAGEM ULTRA QS 12X1L CX',
#  'MINIMO QUE VOCE PRECISA SABER PARA NAO SER UM',
#  'LIVRO O CODIGO DA VINCI PEC',
#  'FAZENDO MEU FILME 3 O ROTEIRO INESPERADO DE FANI EX',
#  '"CONDE DE MONTE CRISTO,O (VOL LL)-SERIE OURO 52 - MARTIN CLARET"',
#  'DESASTRE IMINENTE EX',
#  'O CAPITAL NO SECULO XXI EX',
#  'CONTOS ESCOLHIDOS-MACHADO DE ASSIS-65 - MARTIN CLARET',
#  'EMMA - 4 - EDICAO ESPECIAL - MARTIN CLARET',
#  '"GUARANI,O-17 - MARTIN CLARET"',
#  'ALICE NO PAIS DAS MARAVILHAS',
#  'DIARIO DO SUBSOLO - 321 - MARTIN CLARET',
#  'MEMORIAS POSTUMAS DE BRAS CUBAS',
#  '"LIVRO - REVOLTA DE ATLAS, A PC"',
#  'E NAO SOBROU NENHUM',
#  'LIVRO PONTO DE IMPACTO PEC',
#  '"VALE DO TERROR, O - 290 - MARTIN CLARET"',
#  'LV P TOP FLOR ULTRA QS 12X1L CX',
#  'MEMORIAS DE SHERLOCK HOLMES-214 - MARTIN CLARET',
#  '"WILL & WILL UM NOME, UM DESTINO EX"',
#  'SONETOS-LUIS DE CAMOES-16 - MARTIN CLARET',
#  'ANIMAL FARM',
#  '"GRACA DA COISA, A - CONVENCIONAL PC"',
#  'O CODIGO BRO EX',
#  'LIVRO INFERNO PEC',
#  'UMA PAGINA DE CADA VEZ EX',
#  'MEMORIAS POSTUMAS DE BRAS CUBAS-18 - MARTIN CLARET',
#  '"ANTICRISTO,O-50 - MARTIN CLARET"',
#  'O PODER DO HABITO POR QUE FAZEMOS O QUE FAZEMOS EX',
#  '"PROVA DO CEU, UMA"',
#  'ASSIM FALOU ZARATUSTRA-22 - MARTIN CLARET',
#  'A TORMENTA DE ESPADAS AS CRONICAS DE GELO E FOGO EX',
#  'TENTACAO SEM LIMITES 1A ED PC',
#  'BOX DA TRILOGIA CINQUENTA TONS DE CINZA 1A ED. PC',
#  '"ARQUIVOS DE SHERLOCK HOLMES, OS - 11 - MARTIN CLARET"',
#  'TENTACAO SEM LIMITES EX',
#  '"VOLTA DE SHERLOCK HOLMES, A - MARTIN CLARET"',
#  '"AFINIDADES ELETIVAS, AS"',
#  'ANSIEDADE COMO ENFRENTAR O MAL DO SECULO',
#  'LIVRO QUEM MEXEU NO MEU QUEIJO PEC',
#  'SABEDORIA DAS PARABOLAS-13 EDICAO-171 - MARTIN CLARET',
#  'ANSIEDADE COMO ENFRENTAR O MAL DO SECULO A SIN EX',
#  '"PODER DO AGORA, O"',
#  'O PODER DO AGORA EX',
#  'COLECAO DE LIVROS PEDAGOGIA FUNDAMENTAL ( I )',
#  '"LUSIADAS,OS-33 - MARTIN CLARET"',
#  'PO DE LUA EX',
#  'LIVRO CALENDARIO ALUNO ENTRELINHAS',
#  '"FLORES DO MAL, AS"',
#  'DIVINA COMEDIA-SERIE OURO 07 - MARTIN CLARET',
#  'EU ME CHAMO ANTONIO',
#  'LIVRO MANUAL DO CASAL CPS',
#  'LIVRO NAO SE APEGA NAO PEC',
#  '"NAO SE APEGA, NAO"',
#  'COMO FAZER AMIGOS E INFLUENCIAR PESSOAS',
#  '"PAIS INTELIGENTES FORMAM SUCESSORES, NAO HERDEIROS"',
#  'NAO SE APEGA NAO EX',
#  'PERSUASAO - 6 - EDICAO ESPECIAL - MARTIN CLARET',
#  'O SILMARILLION 5 ED. 2011 EX',
#  'LIVRO FILHOS DO EDEN VOL2 PEC',
#  'DEIXE A NEVE CAIR',
#  '"LIVRO - CABANA, A PC"',
#  'A HERDEIRA 1A ED PC',
#  'COMO EU ERA ANTES DE VOCE',
#  'ELEANOR & PARK EX',
#  '"SETE IRMAS, AS"',
#  'ENTRE O AGORA E O SEMPRE EX',
#  '"CULPA E DAS ESTRELAS, A"',
#  'COMO EU ERA ANTES DE VOCE EX',
#  'O LADO BOM DA VIDA EX',
#  'FELICIDADE ROUBADA',
#  'PERSUASAO - 309 - MARTIN CLARET',
#  'CINQUENTA TONS MAIS ESCUROS EX',
#  'LIVRO CINQUENTA TONS DE LIBERDADE PEC',
#  'LIVRO CIDADES DE PAPEL PEC',
#  'CIDADES DE PAPEL',
#  'ARMADILHAS DA MENTE',
#  'A CULPA E DAS ESTRELAS (CAPA FILME) PC',
#  'LIVRO - CONTOS INACABADOS PC',
#  'MUNDO DE SOFIA EX',
#  'EXTRAORDINARIO',
#  'CINQUENTA TONS DE CINZA',
#  '"MENINA QUE ROUBAVA LIVROS, A"',
#  '"REI DE AMARELO, O"',
#  '"VOLTA AO MUNDO EM 80 DIAS,A - MARTIN CLARET"',
#  '"MUNDO DE SOFIA, O"',
#  '"IRMAO ALEMAO, O"',
#  'RAZAO E SENSIBILIDADE - 1 - EDICAO ESPECIAL - MARTIN CLARET',
#  'A GAROTA QUE VOCE DEIXOU PARA TRAS EX',
#  'EXTRAORDINARIO 1A ED. PC',
#  'A CABANA EX',
#  'CRIME E CASTIGO - EDICAO ESPECIAL - MARTIN CLARET',
#  '"GRANDE AMIGO DE DEUS,O"',
#  'SENHORA-73 - MARTIN CLARET',
#  'INFERNO UMA NOVA AVENTURA DE ROBERT LANGDON EX',
#  '"LIV. MENINO DO PIJAMA LISTRADO, O"',
#  'UMA CARTA DE AMOR EX',
#  'JANE EYRE - EDICAO ESPECIAL - MARTIN CLARET',
#  '"LADO BOM DA VIDA, O"',
#  'TEMPOS EXTREMOS',
#  'ORGULHO E PRECONCEITO-243 - MARTIN CLARET',
#  'LIVRO A MALDICAO DO TIGRE PEC',
#  'ENCONTRADA A ESPERA DO FELIZES PARA SEMPRE SER EX',
#  'LIVRO CINQUENTA TONS DE CINZA PEC',
#  'INFERNO',
#  'EXTRAORDINARIO EX',
#  'GAROTA EXEMPLAR',
#  'RAZAO E SENSIBILIDADE/ORGULHO E PRECONCEITO/PERSUASAO - MARTIN CLARET',
#  '"CASAMENTO, O"',
#  '"HORA DA ESTRELA, A"',
#  'LIVRO - 1984 PC',
#  '"CORTICO,O-72 - MARTIN CLARET"',
#  'LIVRO CINQUENTA TONS MAIS ESCUROS PEC',
#  'A REVOLUCAO DOS BICHOS EX',
#  'VIDAS SECAS',
#  'QUEM E VOCE',
#  '"LIVRO DOS ABRACOS, O - POCKET PC"',
#  'LIVRO FILHOS DO EDEN PEC',
#  'GAROTA EXEMPLAR EX',
#  'DOM CASMURRO-1 - MARTIN CLARET',
#  'LOLITA',
#  'PARA ONDE ELA FOI',
#  '"LIVRO DOS MIL DIAS, O"',
#  'DEIXE A NEVE CAIR EX',
#  '"JOGADOR,O-31 - MARTIN CLARET"',
#  '"MISERAVEIS,OS-EDICAO ESPECIAL - MARTIN CLARET"',
#  'O LADO BOM DA VIDA 1A ED. PC',
#  'SE EU FICAR EX',
#  '"PROCESSO,O-41 - MARTIN CLARET"',
#  'CIDADES DE PAPEL EX',
#  'MAZE RUNNER PROVA DE FOGO EX',
#  '"MENINO DO PIJAMA LISTRADO, O"',
#  'LIVRO A TRAVESSIA PEC',
#  'A MENINA QUE ROUBAVA LIVROS EX',
#  'DOM CASMURRO',
#  'LIVRO A CABANA PEC',
#  '"RETRATO DE DORIAN GRAY,O-12 - MARTIN CLARET"',
#  'ESTRANHA PERFEICAO',
#  '"INSUSTENTAVEL LEVEZA DO SER, A"',
#  'UM CASO PERDIDO HOPELESS EX',
#  'LIVRO A CULPA E DAS ESTRELAS PEC',
#  'DRACULA-SERIE OURO 17 - MARTIN CLARET',
#  'UM ESTUDO EM VERMELHO-69 - MARTIN CLARET',
#  'VIVENCIANDO E APREND INF V (CINCO) L1',
#  'LIVRO EF 7O ANO - MEIO AMBIENTE E ATUALIDADES',
#  'CRESCER COM ALEGRIA E FE - 3O ANO',
#  'LIVRO EF 3O ANO - PRATICA PRODUCAO TEXTUAL',
#  'LIVRO EF 6O ANO - MEIO AMBIENTE E ATUALIDADES',
#  'LIVRO EF 5O ANO - PRATICA PRODUCAO TEXTUAL',
#  'KIDS WEB 4 ED2',
#  'LIVRO INTEGRADO 2A SERIE EM L2',
#  'LIVRO EF 6O ANO - PRATICA PRODUCAO TEXTUAL',
#  'LIVRO INTEGRADO 7O ANO EF L1',
#  'LIVRO LOGICA 2',
#  'LIVRO EF 6O ANO - FILOSOFIA',
#  'LIVRO EF 9O ANO - PRATICA PRODUCAO TEXTUAL',
#  'VIVENCIANDO E APREND INF V (CINCO) L2',
#  'LIVRO DO PROF INF III (TRES) L1',
#  'VIVENCIANDO E APREND INF IV (QUATRO) L2',
#  'COLECAO DE LIVROS PEDAGOGIA INFANTIL ( 07 )',
#  'LIVRO EF 1O ANO - LEITURA E ESCRITA ATIVIDADES',
#  'LIVRO EM 3A SERIE - FILOSOFIA E SOCIOLOGIA',
#  'LIVRO EF 9O ANO - ATIVIDADES DE MATEMATICA',
#  'APRENDER E PRATICAR A GRAMATICA - VOL.UNICO',
#  'LD APROVA CONCURSOS - 33633',
#  'LIVRO INTEGRADO 8O ANO EF L2',
#  'LIVRO EM 2A SERIE - ESPANHOL',
#  'LIVRO DO MODERNISMO AOS DIAS ATUAIS',
#  'VIVENCIANDO E APREND INF II (DOIS) L1',
#  'LIVRO EF 6O ANO - ATIVIDADES SUPLEMENTARES L2',
#  'KIDS WEB 5 ED2',
#  'KIDS WEB 2 ED2',
#  'LIVRO EF 9O ANO - ESPANHOL',
#  'LIVRO EF 8O ANO - ATIVIDADES SUPLEMENTARES L1',
#  'DESCOBRINDO A GRAMATICA 7O - NOVA EDICAO',
#  'EU GOSTO MAIS INTEGRADO 3 ANO',
#  'LIVRO EF 4O ANO - PRATICA PRODUCAO TEXTUAL',
#  'LIVRO EF 5O ANO - INGLES',
#  'LIVRO EF 7O ANO - PRATICA PRODUCAO TEXTUAL',
#  'LIVRO EF 6O ANO - ESPANHOL',
#  'LIVRO EM 1A SERIE - PRATICA PRODUCAO TEXTUAL',
#  'LIVRO EF 8O ANO - PRATICA PRODUCAO TEXTUAL',
#  'LIVRO INTEGRADO 7O ANO EF L2',
#  'NOVO-FTD SISTEMA DE ENSINO-MODULO3 - 3O ANO',
#  'CRESCER COM ALEGRIA E FE - 1O ANO',
#  'LIVRO EF 7O ANO - FILOSOFIA',
#  'LIVRO EF 7O ANO - ATIVIDADES SUPLEMENTARES L1',
#  'VIVENCIANDO E APREND INF IV (QUATRO) L1',
#  'LIVRO EM 2A SERIE - PRATICA PRODUCAO TEXTUAL',
#  'LIVRO INTEGRADO 9O ANO EF L1',
#  'ATIVIDADES GRAFOMOTORAS INF V (CINCO)',
#  'KIDS WEB 1 ED2',
#  'LIVRO INTEGRADO 2A SERIE EM L1',
#  'LIVRO EF 8O ANO - MEIO AMBIENTE E ATUALIDADES',
#  'LIVRO EF 4O ANO - FORMACAO HUMANA',
#  'LIVRO EF 7O ANO - ATIVIDADES SUPLEMENTARES L2',
#  'LIVRO EF 1O ANO - PRODUCAO TEXTUAL',
#  'LIVRO EF 2O ANO - LINGUA PORTUGUESA ATIVIDADES',
#  'LIVRO EF 9O ANO - FILOSOFIA',
#  'NUEVO INTERACCION EM ESPANOL - 6OANO - CONS.',
#  'GRAMMAIRE PROGRESSIVE DU FRANCAIS INTERM. 680',
#  'LIVRO DO PROF INF II (DOIS) L1',
#  'GRAMMAIRE PROGRESSIVE DU FRANCAIS DEBUTANT 440 EX.',
#  'KTA-F.CIDADAOS KIT A 4.ANO REF',
#  'LIVRO EF 7O ANO - ESPANHOL',
#  'LIVRO INTEGRADO 9O ANO EF L2',
#  'LIVRO DIDATICO PEDAGOGICO DE FORM.DE COND.VEICULAR (APOSTILA C/162 PG.)',
#  'BRINCANDO COM AS LETRAS',
#  'LIVRO EDUCACIONAL - STANDARD',
#  'LIVRO EF 5O ANO - FORMACAO HUMANA',
#  'LIVRO EF 2O ANO - PRODUCAO TEXTUAL',
#  'LIVRO EM 1A SERIE - FILOSOFIA E SOCIOLOGIA',
#  'ELOGIO DA LOUCURA-37 - MARTIN CLARET',
#  'TAO TE CHING-136 - MARTIN CLARET',
#  'LIVRO EM 2A SERIE - FILOSOFIA E SOCIOLOGIA',
#  'EINSTEIN-O ENIGMA DO UNIVERSO-175 - MARTIN CLARET',
#  'O LIVRO DA FILOSOFIA EX',
#  'MAHATMA GANDHI-O APOSTOLO DA NAO-VIOLEN-177 - MARTIN CLARET',
#  '"REPUBLICA,A-36 - MARTIN CLARET"',
#  'DISNEY PATETA FAZ HISTORIA',
#  '"PEQUENO PRINCIPE, O"',
#  'LV DIARIO DE UM BAN VOL6 CASA DOS HORRORES',
#  'CLASSICOS INFANTIS - OS TRES PORQUINHOS',
#  'FAZENDO MEU FILME 2 FANI NA TERRA DA RAINHA EX',
#  'DIARIO DE BANANA MARE DE AZAR VIR',
#  'HISTORIAS BIBLICAS',
#  'O SILENCIO DE JULIA COLECAO ARCA DE NOE',
#  'LV DIARIO DE UM BANANA VOL 4 DIAS DE CAO',
#  '"ARCA DE NOE, A"',
#  'COLINS COLOURS',
#  '111 POEMAS PARA CRIANCAS',
#  'CLASSICOS TODOLIVRO: BAMBI',
#  'LV DIARIO DE UM BAN VOL5 VERDADE NUA E CRUA',
#  'O PEQUENO PRINCIPE BROCHURA EX',
#  'LIVRO PEQUENO PRINCIPE PEC',
#  'LIVRO O PEQUENO PRINCIPE',
#  'MEU PRIMEIRO LIVRO DE CONTOS DE FADAS',
#  'LIVRO LITERATURA PASSEIO NO TREM DA POESIA',
#  'NARUTO # 21',
#  'FAZENDO MEU FILME 1 A ESTREIA DE FANI 2 ED. 2 EX',
#  'AS VANTAGENS DE SER INVISIVEL EX',
#  'LIVRO CLASSICOS HIST ENCANT 10V BRASILEIT',
#  'CIDADE DO FOGO CELESTIAL OS INSTRUMENTOS MORTAIS EX',
#  'VIAGEM AO CENTRO DA TERRA-160 - MARTIN CLARET',
#  'POLLYANNA MOCA-273 - MARTIN CLARET',
#  'NARUTO # 28',
#  'LARANJA MECANICA EX',
#  'A PIRAMIDE VERMELHA LIVRO 1 EX',
#  'O SANGUE DO OLIMPO SERIE OS HEROIS DO OLIMPO EX',
#  'CIDADE DOS OSSOS OS INSTRUMENTOS MORTAIS VOL. EX',
#  '"LIVRO JOHNNY, ESTA NOITE PEDIRAO A SUA ALMA - LUCIO BARRETO"',
#  'NARUTO # 25',
#  'NARUTO # 35',
#  'MINHA VIDA FORA DE SERIE 1 TEMPORADA EX',
#  'NARUTO # 36',
#  'NARUTO # 29',
#  'NATE ESTA NA AREA',
#  'CIDADE DE VIDRO OS INSTRUMENTOS MORTAIS VOL. 3 EX',
#  'CIDADES DAS ALMAS PERDIDAS OS INSTRUMENTOS MORTA EX',
#  'NARUTO # 32',
#  'NARUTO # 38',
#  'MAZE RUNNER A CURA MORTAL EX',
#  '"PEQUENO PRINCIPE, O (EDICAO LUXO)"',
#  'NARUTO # 22',
#  'NARUTO # 24',
#  '"LIVRO - ATE MAIS, E OBRIGADO PELOS PEIXES! - VOL.4 - COLECAO GUIA DOS MOCHILEIROS DAS GALAXIAS PC"',
#  'LV DIARIO DE UM BANANA VOL 7 SEGURANDO VELA',
#  'HARRY POTTER E A PEDRA FILOSOFAL 1 EX',
#  '"LIVRO - PIRAMIDE VERMELHA, A PC"',
#  'NARUTO # 33',
#  'MINHA VIDA FORA DE SERIE 2 TEMPORADA EX',
#  'NARUTO # 37',
#  'NARUTO # 30',
#  '"DOADOR DE MEMORIAS, O"',
#  'O CODEX DOS CACADORES DE SOMBRAS EX',
#  '"LIVRO - VIDA, O UNIVERSO E TUDO MAIS, A - COLECAO GUIA DOS MOCHILEIROS DAS GALAXIAS PC"',
#  'AS CRONICAS DE NARNIA VOLUME UNICO EX',
#  'NARUTO # 31',
#  'POLLYANNA-264 - MARTIN CLARET',
#  'A ESCOLHA 1A ED PC',
#  'CIDADE DOS ANJOS CAIDOS OS INSTRUMENTOS MORTAIS EX',
#  'LIVRO O MAR DE MONSTROS PEC',
#  'NARUTO # 39',
#  '"ESCOLHA, A"',
#  'DIARIO DE UMA GAROTA NADA POPU',
#  'NARUTO # 23',
#  'O LIVRO COMPLETO DAS ERVAS',
#  'LIVRO HERNIA DE DISCO E DOR CIATICA',
#  'SERIAL KILLERS - ANATOMIA DO MAL - 1A ED. PC',
#  'NOVO CURSO DE DIREITO CIVIL PARTE GERAL VOL. 1 EX',
#  '"GRAMATICA PARA CONCURSOS PUBLICOS, A"',
#  'DIREITO CIVIL BRASILEIRO VOL. 1 PARTE GERAL EX',
#  'GRAMATICA TEORIA E EXERCICIOS - EDICAO RENOVADA',
#  'PORT LING 8 ANO REF 2014',
#  'INTELIGENCIA EMOCIONAL',
#  '"DEMONIO DO MEIO DIA, O"',
#  'PSICOLOGIA SOCIAL CONTEMPORANEA',
#  'FOCO EX',
#  'PERDAS NECESSARIAS',
#  'MENTES PERIGOSAS O PSICOPATA MORA AO LADO',
#  'DO CONTRATO SOCIAL-46 - MARTIN CLARET',
#  'LIVRO - EDICAO ESPECIAL DAS OBRAS PSICOLOGICAS DE SIGMUND FREUD PC',
#  'LIVRO FERIDAS DA ALMA',
#  'LIVRO UM MES EM ORACAO 4',
#  'LIVRO COMO TORNAR-SE AMIGO DE DEUS (3 EM 1)',
#  'LIVRO CASAMENTO BLINDADO PEC',
#  'LITURGIA DIARIA',
#  'SAO FRANCISCO DE ASSIS',
#  'VIVA COM ESPERANCA - LIVRO MISSIONARIO 2015',
#  '"CRISTO COSMICO E OS ESSENIOS, O-313 - MARTIN CLARET"',
#  'LIVRO - COLECAO ANALISE DA INTELIGENCIA DE CRISTO PC',
#  '"MISERAVEIS, OS (VOL. I)-SERIE OURO 53 - MARTIN CLARET"',
#  'CASAMENTO BLINDADO EDI CASAMENTO BLINDADO EDI',
#  'LIVRO DIVERSAS ORACOES DE CURA E LIBERTACAO',
#  'QUEM ME ROUBOU DE MIM',
#  'DEUS NAO ESTA MORTO',
#  '"MENSAGEM VIVA DO CRISTO,A-176 - MARTIN CLARET"',
#  'LIVRO BATALHA ESPIRITUAL PC',
#  'VIGIAR E PUNIR',
#  'LIVRO UM MES EM ORACAO 3',
#  'LIVRO ORACOES DE CURA E LIBERTACAO',
#  'LIVRO A SABEDORIA NOSSA DE CADA DIA PEC',
#  '"IGREJA DA MISERICORDIA, A"',
#  'LIVRO DONS DE FE E MILAGRES',
#  'ADORACAO AO SANTISSIMO SACRAMENTO',
#  'CURSO MEDIO DE CAPACITACAO TEOLOGICA',
#  'QUEM ME ROUBOU DE MIM EX',
#  'CURSO BASICO DE CAPACITACAO TEOLOGICA',
#  'BHAGAVAD GITA-HUBERTO ROHDEN-164 - MARTIN CLARET',
#  'COMO LER O LIVRO DOS PROVERBIO',
#  'JESUS DE NAZARE',
#  'BIBLIA SAGRADA ED.FAMILIA MEDIA CRISTAL',
#  'ANTROPOLOGIA DO ANTIGO TESTAMENTO - EDITORA HAGNOS',
#  'LIVRO OFICIO DA IMACULADA CONCEICAO-EDITORA CANCAO NOVA',
#  'LIVRO MILAGRES PE. REGINALDO MANZOTTI',
#  'AGENDA S.DOM.PERMANENTE 4X384FL',
#  'AGENDA FRAMA PERMANENTE',
#  'AGENDA S.DOM.ALUNO PERMANENTE 10X128FL',
#  'AGENDA TILIBRA PRATIKA PERM.CORES C/05UN',
#  'AGENDA SAO DOMIN PERMANENTE PAG 9805',
#  'AGENDA SAO DOMIN EXEC PERCALUX 9806',
#  'AGENDA S.DOM.ALUNO MY FRIEND 10X128FL',
#  'AGENDA ESCOLAR',
#  'ALMOFADA PILOT P/CARIMBO N 3 AZUL',
#  'RADEX ALMOFADA ASUPER ALCAR N.3 AZ CX/12 R1309',
#  'ALMOFADA RADEX P/CARIMBO N.3 AZUL',
#  'ALMOFADA PARA CARIMBO',
#  'ALMOFADA RADEX P/CARIMBO N.3 PRETA',
#  'ALMOFADA RADEX P/CARIMBO N.2 AZUL',
#  'ALMOFADA CARIMBO PILOT N.2 09 X 06 AZUL',
#  'ALMOFADA SUPER RADEX ALCAR N.3 AZ',
#  'ALMOFADA CARIMBO PILOT N.2 09 X 06 PRETA',
#  'ALMOFADA CARIMBO N2 PILOT',
#  'ALMOFADA CARIMBO N.3 11X08',
#  'ALMOFADA CARIMBO PILOT N.3 11 X 07 AZUL',
#  'ALMOFADA CARIMBO RADEX 10 X 07 N.3 AZUL',
#  'APAGADOR QDO BR RADEX R1290',
#  'APAGADOR PARA QUADRO BRANCO RADEX',
#  'APAGADOR P/QUADRO BRANCO SUPER RADEX',
#  'APONTADOR CIS QUAD. 1 FURO S2217 C/20UN',
#  'APONTADOR F.CASTELL SIMPLES C/2',
#  'APONTADOR MAPED METAL 534019 C/32UN',
#  'APONTADOR FABER C/DEP.NEON C/25UN',
#  'APONTADOR FABER SIMPLES C/50UN',
#  'SERTIC APONTADOR PLAST PEQ QUADRADO 638/12 R8900 CX',
#  'APONTADOR CIS CORACAO C/DEP. 365 C/24UN',
#  'APONT CIS 638 SIMPLES RETANGULAR',
#  'APONTADOR CIS C/DEP.PEQ. 362 C/24UN',
#  'APONTADOR DEP FABER NEON GRANDE',
#  'APONT CIS 637 SIMPLES REDONDO',
#  'APONTADOR COMUM FABER QUADRADO NEON',
#  'APONTADOR DEP CIS PEQUENO CX C/24 UN',
#  'APONT.FABER SIMPLES SORT.50X1 PT',
#  'APONTADOR CIS SIMPLES C/12UN',
#  'APONTADOR MAPED SHAKER 1 FURO 634753',
#  'APONTADOR COMUM MAPED VIVO',
#  'APONTADOR DEP CIS TIPO LAPIS',
#  'APONTADOR CIS 641 C/24UN',
#  'APONTADOR COMUM QUADRADO CX C/24 UN',
#  'APONTADOR CIS C/DEP. 370 C/24UN',
#  'APONT CIS 363 C/DEP E TAMPA PEQ',
#  'APONTADOR COMUM - MAPED',
#  'NOTE FIX 76X102 AMARELO C/100FL',
#  'NOTE FIX 76X102 ROSA C/100FL',
#  'LEMBRETE TILIBRA 600F 08 X 10 COLORIDO BL',
#  'POSTIT 3M 653 38X50 C/04UN AMARELO 100FL',
#  'NOTE FIX 76X102 LARANJA C/100FL',
#  'BLOCO TILIBRA MOVIMEN.CAIXA PEQ 10X100FL',
#  'POST IT 76X102 C/100FLS AZUL NOTEFIX BL',
#  'POST- IT 76X76 C/100FLS',
#  'POSTIT 3M 657 76X102 AMARELO 100FL',
#  'POST IT 76X102 C/100FLS AMARELO BL',
#  'POST IT 38X50 C/04X100FLS AMARELO BL',
#  'POST IT 76X102 C/100FLS LARANJA NOTEFIX BL',
#  'NOTE FIX 76X102 VERDE C/100FL',
#  'CARTAO PONTO MENSAL TILIBRA 150193',
#  'POST IT 76X102 C/100FLS ROSA NOTEFIX BL',
#  'POST IT 76X102 C/100FLS AMARELO NOTEFIX BL',
#  'BLOCO TILIBRA MOVIMEN.CAIXA GDE 10X100FL',
#  'BLOCO TILIBRA P/RECADO C/600FL',
#  'POSTIT 3M 653 38X50 C/04UN NEON 100FL',
#  'CARTAO TILIBRA PONTO MENSAL C/100UN',
#  'NOTA NEUTRA TILIBRA 1/32 50 FOLHAS',
#  'BLOCO TILIBRA NOTA NEUTRA PEQ.2V 20X40JG',
#  'BLOCO TILIBRA NOTA NEUTRA PEQ.1V 20X50FL',
#  'BLOCO TILIBRA NOTA NEUTRA 1/32 - 50X01 V BL',
#  'BLOCO TILIB PEDIDO DE MESA 50X2F C/20 154008 PT',
#  'BLOCO TILIBRA PEDIDO 2 VIAS 20X40JG',
#  'BLOCO TILIBRA PEDIDO 2 VIAS PEQ. 20X40JG',
#  'BLOCO TILIBRA PEDIDO 1/32 - 40X02V.109X1 BL',
#  'BLOCO TILI PEDIDO 1V 1/32 50F 156591',
#  'BLOCO TILIBRA COMANDO 2 CORPOS 20X100FL',
#  'BLOCO TILIBRA COMANDA 02 CORPOS - 100 FL BL',
#  'BLOCO TILIBRA PEDIDO 1/18 - 40X02V.145X2 BL',
#  'BLOCO TILIBRA VALE SEM CANHOTO - 100 FLS BL',
#  'VALE S/CANHOTO 100F',
#  'VALE S/CANHOTO TILIBRA 100FLS',
#  'BLOCO VALE S/CANHOTO TILIBRA 100FLS',
#  'VALE TILIBRA S/ CANHOTO',
#  'ROLO BOB KPR 80X40 MTS TERMSCPT CX 30 UNIDS',
#  'BOBINA FAX 215 X 30 MTS',
#  'BOBINA SILFER 76MMX30M 1 VIA C/30UN',
#  'BOBINA SILFER 76MMX30M 1 VIA',
#  'BOBINA SILFER 80X40 TERMSCPT',
#  'BOBINA TERMO SCRIPT 56X360M PONTO ELET',
#  'BOBINA 80X40 TERMICA AMARELA MAXPRINT',
#  'BOBINA JANDAIA 76MMX30M 1 VIA C/30UN',
#  'BOBINA SILFER 57MMX30M 1 VIA C/30UN',
#  'BOB FAX 215X30M MAXPRINT',
#  'BOBINA TERMICA 80 X 40 (ATO COTEPE) ARTPEL (30 UNID.) CX',
#  'BOBINA JANDAIA 57MMX30M 1 VIA C/30UN',
#  'BOBINA SILFER 76MMX22M 2 VIAS C/30UN',
#  'BOB TERM PA COTEPE 80X80M CX C/16 1',
#  'BOBINA TERMICA MAXPRINT 80X40 PALHA 453196',
#  'BOBINA P/FAX MAXPRINT 215X30',
#  'BOBINA 80 X 40 TERM. KPR SILFER CX C/30 UNID.',
#  'BOB TERM COTEPE 80X80M CX C/16 1',
#  'BOB TERMICA 80X40 PALHA KPR55 SILFER 573',
#  'BORRACHA MERCUR PRIMA BICOLOR 40X1 R0101013 CX',
#  'BORRACHA PONTEIRA BRANCA MERCUR',
#  'BORRACHA PONTEIRA PCT C/100 - MERCUR',
#  'BORRACHA MAPED PRECISION 511100 C/24UN',
#  'BORRACHA LIC. MONSTER HIGH POTE C/24 UN',
#  'BORRACHA MERCUR CLEAN 24X1 PT',
#  'BORRACHA MERCUR PRIMA 40X1 PT',
#  'BORRACHA PONTEIRA C/100 - MERCUR PCT',
#  'BORRACHA MERCUR TR COLOR 36224',
#  'BORRACHA MERCUR OVAL BRANCA 37290',
#  'BORRACHA MERCUR PRIMA CX 40 PCS',
#  'BORRACHA CIS CAP ERASER C/24UN',
#  'BORRACHA ACRILEX CLASSIC 400',
#  'BORRACHA MERCUR RECORD 60',
#  'BORRACHA PONTEIRA MERCUR PCT',
#  'BORRACHA MERCUR BICOLOR',
#  'BORRAC.MERCUR PONT SC/100',
#  'BORRACHA PONTEIRA PCT C/ 100 MERCUR',
#  'BORRACHA BRANCA RECORD 20 CX 20 UN',
#  'BORRACHA BRANCA RECORD 40 CX 40 UN',
#  'BORRACHA FABER FC MAX PLAST NEON C/24UN',
#  'BORRACHA MOLIN SPIDERMAN 14185 C/20UN',
#  'MERCUR BORRACHA OVAL POTE C/18 R601020',
#  'BORRACHA FABER VERDE 0F/7015 C/15UN',
#  'BORRACHA MERCUR PONTEIRA',
#  'BORRACHA BIC NEON SORTIDA 24X1 PT',
#  'BORRACHA PONTEIRA BR MERCUR 37160',
#  'BORRACHA PONTEIRA - MERCUR',
#  'BORRACHA BI-COLOR MERCUR C/40 UN AZ/VM CX',
#  'BORRACHA FABER TK-PLAST BRANCA 42X21 PEQ',
#  'BORRACHA PONTEIRA C/ 100 MERCUR PCT',
#  'BORRACHA TR COLOR MERCUR',
#  'BORRACHA MERCUR PONTEIRA PCT 100 BRANCA',
#  'BORRACHA MERCUR COLOR FLASH 30',
#  'BORRACHA MERCUR OVAL BRANCA',
#  'BORRACHA PRIMA BICOLOR MERCUR',
#  'BORRACHA MERCUR PRIMA 40',
#  'BORRACHA OVAL BRANCA MERCUR',
#  'BORRACHA MERCUR C/3 BI COLOR',
#  'MERCUR BORRACHA RECORD CX/60 R1006-01 CX',
#  'BORRACHA MAPED TECHNIC DUO 011712 C/2UN',
#  'BORRACHA MERCUR CLEAN ROSA C/24',
#  'MERCUR BORRACHA RECORD CX/40 R1005-01 CX',
#  'BORRACHA ZAP ESCOLAR BRANCA 20 C/20UN',
#  'BORRACHA MERCUR RECORD 40X1 PT',
#  'BORRACHA MERCUR RECORD 40 11092',
#  'BORRACHA PONTEIRA MERCUR',
#  'BORRACHA MAPED PRECISION BRANCA',
#  'BORRACHA FABER FC MAX PLAST PEQ C/24UN',
#  'BORRACHA MERCUR PRIMA 11122',
#  'BORRACHA PONTEIRA CX C/100 MERCUR',
#  'BORRACHA PONTEIRA CX C/ 100 MERCUR',
#  'BORRACHA BRANCA PONTEIRA PCT C/ 100 - MERCUR',
#  'BORRACHA 652603 C/24UND FLAMENGO TRIS',
#  'BORRACHA PONTEIRA PCT COM 100 - MERCUR',
#  'BORRACHA SLIM PONTEIRA SACO C/100',
#  'BORRACHA MERCUR PRIMA 2 CORES',
#  'BORRACHA PONTEIRA PCT C/ 100 - MERCUR',
#  'BORRACHA PONTEIRA C/100 MERCUR PCT',
#  'BORRACHA BI-COLOR MERCUR',
#  'BORRACHA CIS COLOR TRIO C/18UN',
#  'BORRACHA MERCUR BICOLOR PRIMA',
#  'BORRACHA PONTEIRA C/ 100 - MERCUR PCT',
#  'BORRACHA BRANCA 20 - MERCUR',
#  'MERCUR BORRACHA PONTEIRA',
#  'SERTIC BORRACHA CIS SPLASH PT/24 416800 PT',
#  'BIC BORRACHA BRANCA C/2 . CT',
#  'BORRACHA PONTEIRA SLIM SACO C/100UN BR PC',
#  'BORRACHA MERCUR RECORD 60X1 PT',
#  'BORRACHA MERCUR DECOR ROSA/BRANCA POT18',
#  'MERCUR BORRACHA PONTEIRA BCA SC/100 RB01030 PT',
#  'BORRACHA MERCUR TR-COLOR',
#  'BORRACHA MERCUR RECORD 20 11085',
#  'BORRACHA ZAP ESCOLAR BRANCA 40 C/40UN',
#  'BORRACHA MERCUR TR-18 BRANCA',
#  'BORRACHA OVAL COLOR MERCUR',
#  'BORRACHA FABER BRANCA 7040 C/40UN',
#  'BORRACHA CIS DADINHOS POTE 24 UN',
#  'BORRACHA MERCUR 60',
#  'BORRACHA PONTEIRA BRANCA C/100 - MERCUR PCT',
#  'BORRACHA MERCUR RECORD 60 11108',
#  'BORRACHA MERCUR TR 18 POTE 36231',
#  'BORRACHA MERCUR RECORD 20',
#  'BORRACHA F.CASTELL C/CINTA OFFICE7024N',
#  'BORRACHA CIS FANTASIA PONTEIRA C/96',
#  'BORRACHA TR18 POTE C/18 36231 MERCUR',
#  'BORRACHA PONTEIRA MERCUR PCT C/100',
#  'BORRACHA RECORD 40 C3 B01010301008 1',
#  'BORRACHA MERCUR BRANCA 20',
#  'BORRACHA CLASSIC 200 ACRILEX 21920',
#  'BORRACHA CIS FANTASIA NEON C/24',
#  'BORRACHA MERCUR PONT.BCA 100X1 PT',
#  'BORRACHA CIS SPLASH POTE 24 UN',
#  'BORRACHA BIC PLASTICA NEON C2',
#  'BORRACHA PONTEIRA MERCUR C/100 PCT',
#  'BORRACHA PONTEIRA BRANCA C/ 100 MERCUR PCT',
#  'BORRACHA ACRILEX CLASSIC 200 C/20UN',
#  'BORRACHA FABER TK-NEON 24X1 PT',
#  'BORRACHA ACRILEX C/CAPA PLASTICA C/24UN',
#  'BORRACHA PONTEIRA (MERCUR)',
#  'BORRACHA CIS DADINHOS C/24UN',
#  'BORRACHA MERCUR RECORD 20X1 PT',
#  'BORRACHA MERCUR TR DECORADA BR/PT C/18UN PT',
#  'BORRACHA MERCUR OVAL COLOR AZUL/ROSA',
#  'BORRACHA LIC. BARBIE',
#  'BORRACHA MERCUR PONTEIRA SACO C/100',
#  'MERCUR BORRACHA PRIMA CX/40 101013 CX',
#  'BORRACHA ACRILEX CLASSIC 400 C/40UN',
#  'CADERNETA 1/8 MEDIA 48FLS T SOL',
#  'CADERNETA MEDIA TERRA DO SOL',
#  'CADERNETA PANAMERICANA 1/16 40 FLS CX/480 13132',
#  'CADERNETA S.DOMING.MEDIA SILVER 10X80FL',
#  'CADERNETA 1/8 48 FLS - 240 UNID CX',
#  'CADERNETA PANAMERICANA 1/8 48 FLS CX/320 13133',
#  'CADERNETA S.DOMING.MEDIA FRIEND 10X80FL',
#  'CADERNETA TERRA DO SOL 40FL BOLSO',
#  'CADERNETA S.DOMING. MEDIA SISSI 10X80FL',
#  'CADERNETA TERRA DO SOL 48FL MEDIA 1/8',
#  'CADERNETA 1/8 ESP. 48FLS CAPA FLEXIVEL',
#  'CADERNETA 1/16 ESP. 40FLS APONTAMENTO',
#  'CADERNETA PANAMERICANA PEQUENA 40X40FL',
#  'CAD TILIBRA C.D.GOD OF WAR 16X1 2X320FL',
#  'CAD TILIBRA C.D.GOD OF WAR 12X1 4X240FL',
#  'CAD S.DOMING. C.D. 1/4 SISSI 10X96FL',
#  'CAD PANAMERICANA C.D ESPIRAL 1/4 96 FLS CX/60 13138',
#  'CADERNO CD 12M 240FLS CURTIR PANAMERICAN',
#  'CAD CD UNIV BEN10 1M 96F 7891027140946 PC/4 PC',
#  'CAD MAXIMA C.D. LINDINHAS 15X1 3X300FL',
#  'CAD MAXIMA C.D. MAXIGIRLS 15X1 3X300FL',
#  'CAD UNIV CD LIGHT 10M 200FLS PEC',
#  'CAD MAXIMA C.D. LINDINHAS 1X1 6X96FL',
#  'CAD CREDEAL CD 10M 200F A/B TECNOCAR 1UN',
#  'CAD FORONI C.D JUDY 12X1 4X240FL',
#  'CADERNO 200 FOLHAS CAPA DURA',
#  'CAD.12 X 1 C.DURA 240FLS MASC. MAIS+',
#  'PANAMERICANA CAD C.D PETITE 10X1 200 FLS CX/24 PT/3 R13193',
#  'CAD UNIV CD LIGHT 12X1 240FLS PEC',
#  'CADERNO CD 15M 300FLS MOTOS 1040PANAMERI',
#  'CADERNO 1/4 BROCHURA 48 FLS',
#  'CADERNO CD 20M 400FL VIRTUAL CAR PANAMER',
#  'CAD S.DOMING. C.D. 1/4 SILVER 10X96FL',
#  'CAD SAO DOMIN 1/4 200F MY FRIEND',
#  'CADERNO UNIV. 1X1 96FLS MAIS . - TILIBRA',
#  'CAD JANDAIA C.D.1/4 BROC.AZUL 5X96FL',
#  'CADERNO COM ESPIRAL 1/4 C/ 48 FOLHAS',
#  'CAD TILIBRA C.D.SIMPSONS 10X1 4X200FL',
#  'CAD PANAMERICANA C.D ESPIRAL 1/4 200 FLS CX/30 13139',
#  'CAD CREDEAL 1/4 ESPIR 48F PAISAG 20X48F PC',
#  'CAD UNIV CD SWEETNESS 1X1 96FLS PEC',
#  'CAD.10 X 1 LIC. 200FLS JUDY',
#  'CAD.01 MAT.LIC. 96FLS X-RACING',
#  'CAD MAXIMA C.D. FASH. GIRLS 15X1 3X300FL',
#  'CAD FORONI C.D MARIE 12X1 4X240FL',
#  'CADERNO CD 20M 400FLS MARGARIDA PANAMERI',
#  'CAD MAXIMA C.D. XSPORTS 15X1 3X300FL',
#  'CADERNO 12 MATERIAS CAPA DURA',
#  'CADERNO CD 15M 300FLS DARK DAY PANAMERIC',
#  'CAD S.DOMING. C.D. 1/4 MY FRIEND 5X200FL',
#  'CADERNO CD 12M 240FLS SPEED PANAMERICAN PC',
#  'CAD.BROCHURAO LIC. 60FLS BARBIE',
#  'CAD 60FL BROCHURAO PANAMERICANA 3057',
#  'CAD FORONI BROCHURAO 60FL PEPPA 10UN',
#  'CAD S.DOMING.BROCHURAO 60FL SISSI 10UN',
#  'CADERNO CD 15M 300FLS MARGARIDA PANAME',
#  'CAD S.DOMING. C.D. 1/4 DEBBY 10X96FL',
#  'CAD MAXIMA C.D. PATCHWORK 1X1 6X96FL',
#  'CAD TILIBRA C.FORTE 1/4 96FL PRINC. 10UN',
#  'CADERNO DE DESENHO - CREDEAL',
#  'CAD TILIBRA C.D.JOLIE 1X1 4X96FL',
#  'CADERNO CD 12M 240FLS ARTE DIGITAL PANAM',
#  'CAD MAXIMA C.D. XMOTO 1X1 6X96FL',
#  'CAD FORONI BROCHURAO 60FL MARIE 10UN',
#  'CAD MAXIMA C.D. XSTUDIO 15X1 3X300FL',
#  'CAD FORONI C.D BARBIE 10X1 4X200FL',
#  'CAD ESC 12X1 MA CHERIE',
#  'CAD PANAMERICANA C.D.1/4 ESPIRAL 5X200FL',
#  'CAD CD UNIV CHAVES 10M 200F 7891027143220 PC/4 PC',
#  'CADERNO ESPIRAL 96FOLHAS',
#  'CAD ESC 12X1 HOT MACHINE CD',
#  'CAD MAXIMA C.D. XSPORTS 1X1 6X96FL',
#  'CAD JANDAIA C.D.1/4 BROC.LARANJA 5X96FL',
#  'CAD MAXIMA C.D. XMOTO 10X1 4X200FL',
#  'CAD S.DOMING.BROCHURAO 60FL SILVER 10UN',
#  'CAD 1/4 48 FLS TERRA DO SOL',
#  'CAD.CD CAPRICHO 10X1 200FLS',
#  'ATIVIDADES GRAFOMOTORAS INF IV (QUATRO)',
#  'CAD FORONI BROCHURA 48FL JUDY 10UN',
#  'CAD CD SERTAN 12M 240F PANAMERICANA 1221',
#  'CAD JANDAIA C.D.1/4 BROC.AMAR 5X96FL',
#  'CAD MAXIMA C.D. X-SURFING 15X1 3X300FL',
#  'CAD S.DOMING. C.D. 10X1 SISSI 4X200FL',
#  'CAD UNIV CD LIGHT 1M 96FLS PEC',
#  'CAD JANDAIA C.D.1/4 BROC.VERDE 10X48FL',
#  'CAD JANDAIA C.FORTE 60FL CONT FADA 10UN',
#  'PANAMERICANA CAD C.D ESPIRAL 1/4 96 FLS PT/5 CX/60 13138',
#  'CAD 1/4 ESPIRAL 048FLS CAPA FLEXIVEL',
#  'CADERNO TILIBRA 96FLS MAIS+',
#  'CAD TILIBRA C.FORTE 1/4 96FL JOLIE 10UN',
#  'CAD ESC 15X1 HOT MACHINE CD',
#  'CAD.KAJ CD 1/4 MINHAS AMIGAS 96F',
#  'CAD S.DOMING. C.D. 10X1 DEBBY 4X200FL',
#  'CAD JANDAIA 96F BROCH UNIV CD PETIT POA',
#  'CAD MAXIMA C.D. XSPORTS 12X1 4X240FL',
#  'CAD MAXIMA C.D. XMOTO 20X1 2X400FL',
#  'CAD MAXIMA C.D. XSPORTS 10X1 4X200FL',
#  'CAD JANDAIA 96F BROCH UNIV CD CONTO FADA',
#  'CAD.KAJ CD.U SURF 15M 300F',
#  'CAD ESC 10X1 MA CHERIE',
#  'FICHARIO ACP CHARME C/ GLITTER 19623',
#  'CAD FORONI C.D AMIGAS 12X1 4X240FL',
#  'CAD UNIV CD PLACAS HUMOR 10X1 200FLS PEC',
#  'CAD JANDAIA C.D.1/4 BROC.VERDE 5X96FL',
#  'CAD.10 X 1 C.DURA 200FLS MASC. MAIS+',
#  'PANAMERICANA CAD C.D HAPPY DAYS15X1 300FLS PT/2 CX/12 1022',
#  'CADERNO CD 10M 200FLS HAPPY DAYS PANAMER',
#  'CAD MAXIMA C.D. MAXICARS 15X1 3X300FL',
#  'CAD S.DOMING. C.D. 1X1 DEBBY 4X96FL',
#  'CAD TILIBRA C.D.BEN10 1X1 4X96FL',
#  'CAD TILIBRA C.D.ASSASSINS 10X1 4X200FL',
#  'CAD TILIBRA C.FORTE 60FL JOLIE 10UN',
#  'CAD MAXIMA C.D. PATCHWORK 10X1 4X200FL',
#  'CADERNO CD 10M 200FLS MOTOS PANAMERICAN',
#  'CAD S.DOMING. C.D. 15X1 JORDANA 2X300FL',
#  'CAD MAXIMA C.D. LINDINHAS 20X1 2X400FL',
#  'CAD MAXIMA C.D. LINDINHAS 10X1 4X200FL',
#  'CADERNO 1/4 COSTURADO AZUL MAIS 96FLS UNI TILIBRA',
#  'CAD SAO DOMIN 10.1 200F SILVER',
#  'CAD TILIBRA C.FORTE 1/4 48FL JOLIE 20UN',
#  'CAD MAXIMA C.D. MAXICARS 1X1 6X96FL',
#  'CAD TILIBRA C.D.JOLIE 12X1 4X240FL',
#  'CAD S.DOMING. C.D. 1/4 FREEDOM 5X200FL',
#  'CAD ESC 15X1 BELLA',
#  'PANAMERICANA CAD C.D ESPIRAL 1/4 200 FLS PT/5 CX/30 13139',
#  'CAD S.DOMING. C.D. 1/4 SISSI 5X200FL',
#  'CAD MAXIMA C.D. MAXIGIRLS 20X1 2X400FL',
#  'CAD TERRA DO SOL 1/4 48F ESPIRAL',
#  'CAD JANDAIA C.D.1/4 BROC.VERM 5X96FL',
#  'CAD MAXIMA C.D. XPHOTO 12X1 4X240FL',
#  'CAD MAXIMA C.D. XMOTO 12X1 4X240FL',
#  'CAD S.DOMING.BROCHURAO 60FL DEBBY 10UN',
#  'CAD FORONI BROCHURAO 60FL COLOR 10UN',
#  'CADERNO DE DESENHO',
#  'CAD UNIV CD SCHOOL BASIC 1M 96FLS PEC',
#  'CAD CD UNIV SNOOPY 10M 200F 7891313604695 PC/4 PC',
#  'CADERNO CD 12M 240FLS PETITE PANAMERICAN',
#  'CAD DESENHO TILIBRA CD S/S JOLIE 4X96FL',
#  'CAD FORONI BROCHURA 48FL COLOR 20UN',
#  'CAD.KAJ CD 1/4 SPEED MACHINE 96F',
#  'CAD ESC 01X1 HOT MACHINE CD',
#  'CADERNO 10 X 1 CAPA DURA 200 FLS',
#  'CADERNO CD 12M 240FLS MOTOS PANAMERICANA',
#  'CADERNO CD 12M 240FLS DARK PANAMERI',
#  'CAD PAUTA DUPLA AZ BROCHURAO GRAFICA CAMPOS 30 FLS',
#  'CAD MAXIMA C.D. XMOTO 15X1 3X300FL',
#  'CAD JANDAIA BROCHURA UNIV CONTO DE FADAS 60 FLS PT/10 58148 PT',
#  'CAD CREDEAL 1/4 CD 01M 96F POP BY 1UN',
#  'CAD PANAMERICANA BROCHURAO 60 FLS PT/15 CX/6 13057 PT',
#  'CAD.BROCHURAO C.DURA 96FLS JOLIE',
#  'CADERNO 1/4 48FLS',
#  'CADERNO BROCHURA JANDAIA 96FLS',
#  'CADERNO UNIVERSITARIO 10 MATERIAS CAPA DURA COM 200 FOLHAS',
#  'CAD.1/4 BROCHURA 96FLS (COMMODITY)',
#  'CAD S.DOMING. C.D. 1/4 MY FRIEND 10X96FL',
#  'CAD CD 10X1 200 FLS NO STRESS 1',
#  'CAD MAXIMA C.D. MAXICARS 12X1 4X240FL',
#  'CADERNO 1/4 ESPIRAL 48 FOLHAS',
#  'PANAMERICANA CAD C.D HAPPY DAYS 20X1 400FLS PT/2 CX/12 1023',
#  'CAD.01 MAT.LIC. 96FLS PRINCESAS',
#  'CADERNO CD 15M 300FLS HAPPY DAYS PANAME',
#  'CADERNO CD 1/4 ESPIRAL 96FLS 13138 PANAM',
#  'CAD UNIV CD SCHOOL BASIC 10M 200FLS PEC',
#  'CAD FORONI BROCHURA 96FL PEPPA 10UN',
#  'CAD FORONI C.D MARIE 10X1 4X200FL',
#  'CAD TILIBRA C.FORTE 60FL SPIDER 10UN',
#  'CAD TILIBRA C.D.SIMPSONS 16X1 2X320FL',
#  'CAD.1/4 ESPIRAL 048FLS CAPA FLEXIVEL',
#  'CAD. BROCHURA FORONI 48FLS',
#  'CAD S.DOMING. C.D. 1/4 MOTOS 10X96FL',
#  'CAD TERRA DO SOL 1/4 96F ESPIRAL',
#  'CAD TILIBRA C.D.JOLIE 16X1 2X320FL',
#  'CAD.1/4 BROCHURA 48FLS (COMMODITY)',
#  'CAD FORONI BROCHURAO 60FL MORANG. 10UN',
#  'CAD MAXIMA C.D. PATCHWORK 12X1 4X240FL',
#  'CAD TILIBRA C.D.JOLIE 10X1 4X200FL',
#  'CAD MAXIMA C.D. LINDINHAS 12X1 4X240FL',
#  'CAD TILIBRA C.D.BEN10 10X1 4X200FL',
#  'CAD CREDEAL 1/4 ESPIR 96F PAISAG 1UN',
#  'CADERNO CAPA DURA C/ 10 MATERIAS',
#  'CAD T.SOL 1/4 48FLS ESPIRAL',
#  'CAD.CALIGRAFIA BROCHURA 014 PGS NR.01',
#  'CADERNO DE PAUTA DUPLA',
#  'CAD.CALIGRAFIA BROCHURA 015 PGS NR.03',
#  'CAD JANDAIA BROC 1/4 PD CALIGR 20X40FL',
#  'CAD JANDAIA BROC 1/4 PD CALIGR 20X40',
#  'CAD.CALIGRAFIA BROCHURA 014 PGS PRE',
#  'CAD.CALIGRAFIA 40FLS PAUTA DUPLA',
#  'ARQUIVO MORTO PAPELAO FRAMA C/25UN',
#  'CAIXA ARQUIVO MORTO POLIBRAS VERDE',
#  'ARQUIVO MORTO POLIONDA POLIBRAS AMARELO',
#  'CAIXA ARQUIVO PLÃ\x81STICO',
#  'CAIXA PARA ARQUIVO MORTO',
#  'CAIXA ARQUIVO MORTO POLIONDA POLIBRAS',
#  'ARQUIVO MORTO POLIONDA ALAPLAST AZUL',
#  'CAIXA ARQUIVO PLASTICA POLIBRAS',
#  'CAIXA ARQUIVO MORTO SAO CARLOS UND',
#  'ARQUIVO MORTO PRATICO AZ ALAPLAST',
#  'ARQUIVO MORTO POLIONDA POLIBRAS CINZA',
#  'ARQUIVO MORTO POLIONDA POLIBRAS AZUL',
#  'ARQUIVO MORTO PAPELAO 34 X 24 X 13',
#  'ARQUIVO MORTO PAPELAO FRAMA',
#  'ARQUIVO MORTO POLIONDA POLIBRAS VERDE',
#  'ARQUIVO MORTO POLIONDA POLIBRAS',
#  'CAIXA ARQUIVO MORTO PAPELAO',
#  'ARQUIVO MORTO POLIONDA ALAPLAST VERDE',
#  'ARQUIVO MORTO POLIBRAS POLIONDA',
#  'CALCULADORA CLASSE CLA6809A',
#  'CALCULADORA CLASSE CLA-8961',
#  'CALCULADORA CLASSE DE MESA',
#  'CALCULADORA CLASSE DE MESA 12DIG 1048B',
#  'CALCULADORA CLASSE CLA-402',
#  'CALCULADORA COM CANETA E PORTA CARTOES',
#  'CALCULADORA CLASSE CLA-310 8ML',
#  'CALCULADORA CLASSE CLA-2804',
#  'CALCULADORA DE MESA 12 DIGITOS',
#  'CALCULADORA BOLSO 08 DIG./CORDAO',
#  '***CALCULADORA FINANCEIRA HP 12C',
#  'CALCULADORA TS-2812',
#  'CALCULADORA FINANCEIRA HP 12C GOLD PC',
#  'CALCULADORA CLASSE CLA 6809',
#  'CALCULADORA SHENG KD-8822',
#  'CALCULADORA SHENG TS 3822B',
#  'CALCULADORA CLASSE DE MESA 12DIG 9688B',
#  'CALCULADORA MESA 12 DIG.SOLAR/BATERIA',
#  '"90000440-CANETA ESF 1,0 AZ CRISTAL BIC"',
#  'BIC CN ESF CRIST MED VERM 1X50 DY',
#  'HIDROCOR FABER 12 CORES LAVAVEL ES',
#  'CANETA PRETA COMPACTOR ECONOMIC',
#  'CANETA COMPACTOR 07',
#  'CANETA FABER TRILUX CX 50 UN PRETA',
#  'CANETA BIC AZUL',
#  'CANETA 0.7 AZUL 00011 COMPACTOR',
#  'MARC RETROP 2.0 AZ PILOT',
#  'CANETA BIC CRISTAL CX C/50 UN VERMELHA',
#  'CANETA COMPACTOR ESCRITA FINA PRETA',
#  'CANETA COMP.07 AZUL 100X1 PT',
#  'BIC CANETA CRISTAL FINA PT CX/100 902454 CX',
#  'CANETA COMPACTOR 0.7 FINA CX 025 PINK',
#  'CANETA ESFEROGRAFICA AZUL 0.7 - COMPACTOR',
#  'COMPACTOR CANETA 0.7 PT C/50 CX',
#  'CANETA COMPACTOR 0.7 FINA PRETA',
#  'CANETA COMPACTOR MICROLINE VIOLE C/12UN',
#  'CANETA 0.7 PRET 851 COMPACTOR',
#  'CANETA ESF.COMPACTOR 07 VERMEL-C',
#  'CANETA COMPACTOR 0.7 ESC.FINA AZUL',
#  'CANETA ESF 0.8 FINA AZ BIC',
#  'CANETA PILOT BP-S 0.7 PONTA DE ACO AZ',
#  'CANETA COMPACTOR ECONOMIC CX 50 AZUL',
#  'CANETA COMPACTOR ECONOMIC CX 50 PRETA',
#  'CANETA BIC CRISTAL CX C/50 UN PRETA',
#  'CANETA COMPACTOR NEO-PEN GIGANTE C/12',
#  'CANETA FABER TRILUX COLORS ROXO C/12UN',
#  'CANETA COMPACTOR MICROLINE AZUL C/12UN',
#  'CANETA NEO PEN COMPACTOR 6CORES',
#  'CANETA FABER TRILUX FINA PRETA C/50UN',
#  'CANETA COMPACTOR 0.7 FINA CX 100 VERM',
#  'CANETA MICROLINE FINE 0.4MM ROSA',
#  'CANETA COMPACTOR 07 C/50 PRETA',
#  'CANETA COMPACTOR MICROLINE LARAN C/12UN',
#  'HIDROCOR COMPACTOR 06 CORES MIRIM ES',
#  'CANETA BIC PRETA 50UNID. CX',
#  'CANETA COMPACTOR ECONOMIC PRETA',
#  'CANETA COMPACTOR 0.7 FINA CX 025 AZUL',
#  'CANETA COMPACTOR MICROLINE 0.4MM ROSA',
#  'CANETA COMPACTOR 07 CX 50 AZUL',
#  'CANETA COMPACTOR 07 C/50 AZUL CTX',
#  'CANETA CIS HAPPY C/24UN',
#  'CANETA COMPACTOR 07 C/25 AZUL',
#  'BIC CANETA CRISTAL FINA C/50 A CE',
#  'CANETA CIS BLANC 1.0 SORTIDAS',
#  'CANETA COMPACTOR 0.7MM VERMELHA',
#  'CANETA COMP.07 AZUL 50X1 PT',
#  'BIC CANETA CRISTAL FINA C/50 V CE',
#  'CANETA BIC CRIS.FINA PRET.50X1 PT',
#  'CANETA BIC CRISTAL AZUL 50UND CX',
#  'CANETA BIC CRISTAL FINA PT C/100 902454',
#  'CANETA ESFEROGRAFICA AZUL CX C/ 50 - TRIS',
#  'CANETA CROWN CAPRICCI ESFEROGRAFICA',
#  'HIDROCOR COMPACTOR 06 CORES GIGANTE',
#  ...]

# %%
vectorizer_train = CountVectorizer()
X_train = vectorizer_train.fit_transform(X_train)

# %%
vectorizer_test = CountVectorizer(vocabulary=vectorizer_train.vocabulary_)
X_test = vectorizer_test.transform(X_test)

# %%
model = MultinomialNB()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#                                       precision    recall  f1-score   support
#
#             ACESSORIO DE INFORMATICA       0.90      0.75      0.82        24
#               ACESSORIO DE VESTUARIO       0.88      0.78      0.82        27
#                  ACESSORIO DE VIAGEM       0.00      0.00      0.00         3
# ACESSORIO E EQUIPAMENTO PARA ESPORTE       0.83      0.38      0.53        13
#                 ACESSORIO ELETRONICO       0.93      0.45      0.60        29
#                    ACESSORIO MUSICAL       0.00      0.00      0.00         2
#                  ACESSORIO PARA BEBE       0.00      0.00      0.00         6
#                ACESSORIO PARA BELEZA       0.96      0.64      0.77        42
#               ACESSORIO PARA CALCADO       0.00      0.00      0.00         1
#               ACESSORIO PARA CELULAR       0.00      0.00      0.00         2
#                 ACESSORIO PARA OTICA       0.00      0.00      0.00         1
#         ACESSORIO PARA TELEFONE FIXO       0.00      0.00      0.00         2
#               ACESSORIO PARA VEICULO       1.00      0.50      0.67        20
#                ACESSORIOS RELIGIOSOS       0.00      0.00      0.00         1
#                               ACUCAR       1.00      0.88      0.94        17
#                             ADOCANTE       1.00      0.62      0.77         8
#                                 AGUA       0.95      0.87      0.91        85
#                           AGUARDENTE       1.00      0.65      0.79        20
#                               ALARME       0.00      0.00      0.00         2
#                ALIMENTO CONDIMENTADO       0.93      0.96      0.94       118
#                 ALIMENTO EM CONSERVA       1.00      0.88      0.93        40
#                 ALIMENTO PARA ANIMAL       0.97      0.73      0.83        44
#                      ALIMENTO PRONTO       1.00      0.33      0.50        18
#                            APERITIVO       0.00      0.00      0.00         2
#                                ARROZ       0.96      0.97      0.96        66
#                ARTIGO PARA DECORACAO       0.00      0.00      0.00         2
#                            AVIAMENTO       0.95      0.72      0.82        25
#                            BIJUTERIA       0.00      0.00      0.00         4
#                             BISCOITO       0.92      0.97      0.94       149
#                           BOMBONIERE       0.87      0.93      0.90       148
#                                 BOTA       1.00      0.25      0.40         4
#                            BRINQUEDO       1.00      0.15      0.27        13
#                                 CAFE       1.00      0.90      0.95        51
#                              CAJUINA       0.00      0.00      0.00         2
#                    CAMA MESA E BANHO       0.50      0.07      0.12        15
#                         CARNE BOVINA       0.77      0.99      0.86        86
#                        CARNE DE AVE        0.86      0.96      0.91        25
#                   CARNE DE CRUSTACEO       1.00      1.00      1.00         3
#                       CARNE DE PEIXE       1.00      0.72      0.84        32
#                          CARNE OVINA       0.00      0.00      0.00         1
#                          CARNE SUINA       1.00      0.73      0.85        15
#                           CARROCERIA       0.00      0.00      0.00         1
#                              CELULAR       0.92      0.97      0.94        34
#                               CEREAL       1.00      0.73      0.85        45
#                              CERVEJA       0.98      1.00      0.99       136
#                               CEVADA       0.00      0.00      0.00         1
#                                  CHA       1.00      0.74      0.85        19
#                            CHAMPAGNE       0.00      0.00      0.00         1
#                              CHINELO       0.88      1.00      0.93        43
#                             CHUTEIRA       0.00      0.00      0.00         1
#                          COMBUSTIVEL       1.00      0.64      0.78        22
#                           COSMETICOS       0.79      0.99      0.88       924
#                     DOCE E SOBREMESA       1.00      0.67      0.80        54
#                      ELETRODOMESTICO       0.94      0.94      0.94        52
#                           ELETRONICO       0.86      0.80      0.83        15
#                      ELETROPORTATEIS       0.98      0.91      0.94        45
#              EMBALAGEM PARA PRESENTE       0.00      0.00      0.00         1
#                           ENERGETICO       1.00      0.57      0.73        14
#                              EROTICO       0.00      0.00      0.00         1
#                           ESPECIARIA       1.00      0.75      0.86        28
#                            ESPUMANTE       0.93      1.00      0.96        13
#                  ESTRUTURA FLUTUANTE       0.00      0.00      0.00         1
#                            EXCLUIDOS       0.00      0.00      0.00         1
#                               FARELO       0.00      0.00      0.00         3
#                      FARINHA E AMIDO       0.83      0.96      0.89        90
#                               FEIJAO       0.96      0.87      0.91        30
#                             FERRAGEM       1.00      0.76      0.86        49
#                         FERTILIZANTE       0.00      0.00      0.00         1
#                     FORMAS DE TABACO       1.00      0.67      0.80         3
#                                FRUTA       0.92      0.90      0.91       105
#                                 GAME       1.00      0.20      0.33         5
#                             GENERICO       0.89      0.93      0.91       810
#                              GRANITO       0.91      0.91      0.91        11
#                          HIDROTONICO       0.00      0.00      0.00         1
#                          INFORMATICA       0.94      0.80      0.86        20
#                            ISOTONICO       1.00      0.29      0.44         7
#                           LACTICINIO       0.79      0.96      0.87       258
#                                LEITE       0.91      0.98      0.94       146
#                                LICOR       1.00      0.60      0.75        10
#                                LIVRO       0.91      0.60      0.72        65
#                             MACARRAO       0.96      0.98      0.97        55
#                MAQUINA E EQUIPAMENTO       1.00      0.10      0.18        10
#                              MARMORE       1.00      0.33      0.50         3
#                         MASSA PRONTA       0.00      0.00      0.00         1
#                    MATERIAL ELETRICO       0.91      0.85      0.88        99
#           MATERIAL PARA AGROPECUARIA       1.00      0.25      0.40         4
#             MATERIAL PARA ARTESANATO       1.00      0.33      0.50        12
#             MATERIAL PARA CONSTRUCAO       0.72      0.96      0.82       508
#   MATERIAL PARA ESCRITORIO E ESCOLAR       0.85      0.96      0.90       227
#         MEDICAMENTO NAO CLASSIFICADO       0.71      0.06      0.10        90
#                                  MEL       0.00      0.00      0.00         3
#                       MISTURA PRONTA       1.00      0.76      0.87        51
#                                MOTOR       1.00      0.53      0.70        15
#                         ODONTOLOGICO       0.00      0.00      0.00         3
#                                 OLEO       1.00      0.85      0.92        26
#                                OLHOS       0.00      0.00      0.00         3
#                            ORTOPEDIA       0.00      0.00      0.00         2
#                  OUTROS MEDICAMENTOS       1.00      0.21      0.35        57
#                           OVO DE AVE       1.00      0.88      0.94        17
#                                  PAO       0.98      0.87      0.92        54
#                                PAPEL       1.00      0.81      0.89        26
#      PARTE E ACESSORIO DE RELOJOARIA       0.00      0.00      0.00         1
#            PARTE E PECA PARA VEICULO       0.66      0.89      0.76        57
#                          PECA INTIMA       0.92      0.97      0.94        94
#       PECAS E ACESSORIOS PARA MOVEIS       0.00      0.00      0.00         1
#                           PERFUMARIA       0.94      0.66      0.77        67
#                                  PES       0.00      0.00      0.00         2
#                  PREPARACAO DE CARNE       0.97      0.93      0.95        41
#                  PREPARACAO DE FRUTA       1.00      0.68      0.81        34
#               PRODUTO DE CONFEITARIA       0.94      0.52      0.67        29
#              PRODUTO DE FLORICULTURA       0.00      0.00      0.00         5
#                   PRODUTO DE HIGIENE       0.89      0.95      0.92       184
#                   PRODUTO DE LIMPEZA       0.86      0.98      0.92       396
#                  PRODUTO DESCARTAVEL       0.91      0.85      0.88        81
#                 PRODUTO FARMACEUTICO       0.82      0.88      0.85       398
#                   PRODUTO HOSPITALAR       0.95      0.60      0.74        35
#                        PRODUTO OTICO       0.94      0.62      0.75        24
#                  PRODUTO PARA ANIMAL       1.00      0.09      0.16        35
#             PRODUTO PARA CONSERVACAO       1.00      0.29      0.45        31
#                   PRODUTO PARA FESTA       1.00      0.67      0.80         9
#             PRODUTO PARA ORGANIZACAO       0.88      0.47      0.61        15
#               PRODUTO PARA SEGURANCA       1.00      0.36      0.53        14
#                   PRODUTO PARA SOLDA       1.00      0.20      0.33         5
#                     PROTEINA DE SOJA       0.00      0.00      0.00         3
#                           REFERENCIA       0.94      0.95      0.94      1137
#                         REFRIGERANTE       0.91      1.00      0.95       263
#                              RELOGIO       1.00      0.71      0.83         7
#                              REVISTA       1.00      0.56      0.72        16
#                                ROSTO       0.92      0.20      0.32        56
#                                  RUM       1.00      1.00      1.00         4
#                             SANDALIA       0.93      0.70      0.80        20
#                            SAPATILHA       1.00      0.25      0.40         4
#                               SAPATO       1.00      0.25      0.40         4
#                              SIMILAR       0.86      0.93      0.89      1626
#               SISTEMA DE ALIMENTACAO       0.89      0.80      0.84        20
#                   SISTEMA DE DIRECAO       0.00      0.00      0.00         2
#                  SISTEMA DE ELETRICO       0.95      0.77      0.85        26
#                    SISTEMA DE FREIOS       0.00      0.00      0.00         4
#                 SISTEMA DE SUSPENCAO       1.00      0.25      0.40        12
#               SISTEMA DE TRANSMISSAO       1.00      0.82      0.90        17
#                               SUCATA       1.00      0.27      0.43        11
#                                 SUCO       0.97      0.99      0.98        76
#                        TELEFONE FIXO       1.00      0.33      0.50         3
#                              TEMPERO       0.89      0.90      0.90       112
#                                TENIS       0.83      0.96      0.89        26
#                              TEQUILA       0.00      0.00      0.00         1
#                    TINTA PARA TECIDO       1.00      0.25      0.40         4
#                   TIPO DE FERRAMENTA       0.90      0.93      0.91       122
#                      TIPO DE FOSFORO       1.00      0.60      0.75        10
#                         TIPO DE GRAO       0.92      0.76      0.83        29
#                      TIPO DE MADEIRA       1.00      0.95      0.98        21
#                       TIPO DE MOVEIS       1.00      0.63      0.77        35
#                       TIPO DE PLANTA       0.00      0.00      0.00         4
#                      TIPO DE PRODUTO       0.77      0.30      0.43        33
#                      TIPO DE SEMENTE       0.00      0.00      0.00         4
#                       TIPO DE TABACO       0.00      0.00      0.00         1
#                       TIPO DE TECIDO       1.00      0.67      0.80         3
#                         TIPO DE VELA       1.00      0.50      0.67         2
#                        TIPO DE VIDRO       1.00      0.33      0.50         3
#                                UNHAS       1.00      0.95      0.97        61
#                 UTENSILIO DE LIMPEZA       0.90      0.78      0.84        91
#                  UTENSILIO PARA BEBE       1.00      0.91      0.95        11
#                 UTENSILIO PARA O LAR       0.87      0.74      0.80       148
#                    VEICULO TERRESTRE       1.00      0.62      0.76        21
#                     VERDURA E LEGUME       0.90      0.75      0.82        76
#                             VERMOUTH       0.00      0.00      0.00         1
#                   VESTUARIO FEMININO       0.81      0.60      0.69        35
#                   VESTUARIO INFANTIL       1.00      0.11      0.20         9
#                  VESTUARIO MASCULINO       1.00      0.83      0.91        12
#                  VESTUARIO PARA BEBE       1.00      0.17      0.29         6
#                                VINHO       0.93      1.00      0.97        42
#                                VODKA       1.00      0.67      0.80        12
#                               WHISKY       1.00      0.81      0.90        16
#
#                          avg / total       0.88      0.87      0.86     11320
# C:\Users\Newton\Anaconda3\envs\TensorFlow\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn import metrics

# %%
score = metrics.accuracy_score(y_pred=y_pred, y_true=y_test)

# %%
print('{0:f}'.format(score))
# Out:
# 0.872438

# %%
teste_predict=['EPSON MAGENTO','LILLO BICO','BOV AMERICANA KG','KING 100ML JASMIM']
teste_predict_vect = vectorizer_train.transform(teste_predict) 
model.predict(teste_predict_vect)
# Out:
# array(['ACESSORIO DE INFORMATICA', 'PRODUTO FARMACEUTICO', 'CARNE BOVINA',
#        'PRODUTO DE LIMPEZA'],
#       dtype='<U36')

# %%
pred_prob_list = model.predict_proba(teste_predict_vect).tolist()
pred_prob_list
# Out:
# [[1.2612109437144663e-05,
#   0.12456661669529484,
#   0.003014759766418273,
#   5.0434897371036724e-05,
#   0.0013641372690216212,
#   0.0037379155131576454,
#   0.00033907045789223245,
#   6.302670532503507e-05,
#   0.0002890782165704157,
#   0.0040571731944465915,
#   0.00011337370622270368,
#   0.0001762173392455969,
#   3.782504499997623e-05,
#   0.002737211329597026,
#   0.00011342439793587119,
#   0.0022804781494902104,
#   0.0010330001120631212,
#   2.5224218874289374e-05,
#   0.00817632288907079,
#   0.0024220570391157424,
#   3.78318141791452e-05,
#   1.261286192719194e-05,
#   0.011776291313413725,
#   0.004133076388648512,
#   0.005752402755174777,
#   0.0021161317643463083,
#   1.2612485670944478e-05,
#   0.0006518048835574495,
#   0.005193359625259963,
#   1.2613238205889063e-05,
#   0.0005268482799519008,
#   3.7829557516901805e-05,
#   0.0021407689171849178,
#   0.0007899208752570643,
#   0.012606081320354866,
#   0.014046539949970419,
#   0.0004501684897758248,
#   0.0013931896614221332,
#   0.005279643594835204,
#   0.00020138524945915326,
#   0.0013449899652140079,
#   5.042737807930348e-05,
#   0.010229373304957202,
#   0.003386978012457097,
#   0.0004638530037797429,
#   0.002801504458878231,
#   7.561626529058085e-05,
#   0.002077408950364205,
#   0.00037615279774145974,
#   2.5221209452763484e-05,
#   1.2612109437144663e-05,
#   0.003742603375903481,
#   0.0044471110806694,
#   0.012161421097257567,
#   0.00011337708426055094,
#   0.0017001023562246394,
#   5.0422867580369904e-05,
#   0.00424323780435823,
#   2.5221209452763484e-05,
#   0.001933857273417534,
#   0.043138208099527474,
#   0.006276962070851208,
#   0.004452212698359893,
#   0.0017979337672189885,
#   0.00422405285993675,
#   0.00013850183719811196,
#   0.0019274909086427784,
#   0.0002640037655106723,
#   3.782617302827744e-05,
#   0.0031563653601620525,
#   0.0008975231776283532,
#   6.301731125341331e-05,
#   1.261286192719194e-05,
#   0.0002889236155097665,
#   0.008175297252015575,
#   3.781376841618813e-05,
#   0.00217309425342126,
#   0.00548670746812725,
#   5.0424370990357586e-05,
#   5.042888175827775e-05,
#   0.00021383814290264823,
#   0.010285640078300086,
#   0.0003890257957467411,
#   0.03928319219019411,
#   0.0011554511975759678,
#   0.00011339397746975614,
#   0.05573548742267365,
#   6.302106854599938e-05,
#   5.042888175827775e-05,
#   0.0007748318456151714,
#   3.7829557516901805e-05,
#   0.022196891248087398,
#   0.014152073371669073,
#   0.0005767163139229735,
#   0.004842166766535415,
#   0.0062042612054633624,
#   1.2611733225790488e-05,
#   0.001155043894410147,
#   0.00036381937020208923,
#   0.0005014478380613175,
#   0.009153929887574982,
#   0.0005637109570016604,
#   0.0015539427054237327,
#   0.03375230869738331,
#   0.01827475818014316,
#   0.009144622804571048,
#   0.000213908147354061,
#   0.005449481473749011,
#   0.00033908052949141096,
#   0.0014685978462508171,
#   0.0003391510474422237,
#   0.0028704764376289733,
#   0.00031425282047079016,
#   0.0001888942684792102,
#   0.004856582024560828,
#   0.0013380396302945378,
#   0.0056586091205134675,
#   0.0029364186146268777,
#   1.2613238205889063e-05,
#   0.00665544254230872,
#   0.008517169248944698,
#   0.00016362064421880814,
#   0.00013860503043677062,
#   2.5224971341888912e-05,
#   0.006369108726171246,
#   0.0003016020054652723,
#   0.00417452354523499,
#   0.0035347809175319076,
#   0.0037255986763735168,
#   0.00042720601855887657,
#   0.017260460677227345,
#   0.027700968804451467,
#   0.00853692053500181,
#   0.030931496820962696,
#   0.0038332199103875792,
#   0.002294089124807874,
#   0.0050243106911634135,
#   0.0034562277188921477,
#   0.0012711764171908552,
#   0.000637889624522421,
#   0.001131833399940796,
#   0.0003264347249056102,
#   0.00018870878596485908,
#   3.781827824276823e-05,
#   0.04797211478722663,
#   0.020768880573175493,
#   0.0005725229394885038,
#   0.0013741736175615791,
#   0.005555545226887253,
#   0.0008736738635069549,
#   0.0020164161492561036,
#   0.0006384373475967155,
#   0.0007256792492412774,
#   7.562302781244307e-05,
#   0.055005882802374964,
#   0.0021546851327756307,
#   0.00010069262472957679,
#   0.0003264347249056102,
#   0.002836823060953912,
#   7.5557707391684e-05,
#   0.0005124342417854279,
#   0.001039996560706246,
#   0.0015442675417898818,
#   0.0008625678241813271,
#   0.00859689506357104,
#   0.0008612436566479677,
#   0.01086483548902755,
#   0.00314703120667038,
#   0.00017623307902639744,
#   0.0008951741932488646,
#   0.012820381719949798,
#   0.0011348714755526918,
#   0.004491128045019233,
#   0.0032739276738931763,
#   0.0034976326496637374,
#   0.000289293214946516,
#   0.000490336447061813,
#   0.0036695570826547606,
#   0.0006141097224961806,
#   0.00040198068244837166,
#   0.00042599067472181375,
#   0.0004266354638359239,
#   0.0004261801161721791,
#   2.5222714073759924e-05,
#   0.005392089846249129,
#   0.010030966284455796,
#   0.0013570124857829725,
#   0.013385408297385173,
#   0.001458598347270648,
#   0.006449527643079598,
#   8.823738745504903e-05,
#   0.0034593146140725244,
#   0.0007387374932633241,
#   0.0021654071429521183,
#   0.0008578752685301622,
#   0.0040061944351308726,
#   0.001134369571724725,
#   0.0010222394534051278],
#  [1.8002984086623117e-06,
#   0.0004373601737672423,
#   0.00041478474664957937,
#   7.1973285478605796e-06,
#   0.00019146636837348121,
#   0.0005117637487538571,
#   4.8193134943729325e-05,
#   8.991833214988866e-06,
#   4.1121782716962745e-05,
#   0.0021982466732490347,
#   1.6164088340201765e-05,
#   2.5103731412727317e-05,
#   5.397674464399539e-06,
#   0.0003768800737915881,
#   1.6178546163608365e-05,
#   0.00031645205705193067,
#   0.00014550961158355677,
#   3.60059681732463e-06,
#   0.0010407602413835901,
#   0.0003353301315317489,
#   5.399606575515586e-06,
#   1.800513241407788e-06,
#   0.0014334151759344577,
#   0.0016811948865240675,
#   0.0007627568484342492,
#   0.00029466326867283476,
#   1.800405820228518e-06,
#   9.247001178328728e-05,
#   0.0006890680363927801,
#   1.8006206722012698e-06,
#   7.47981539045951e-05,
#   5.398962423225607e-06,
#   0.0002963947922448229,
#   0.00011209743345835454,
#   0.0014778782820640641,
#   0.0016240711656393008,
#   6.371133730285873e-05,
#   0.00019614240669168332,
#   0.0007042068334251529,
#   2.8688270588446195e-05,
#   0.0001878367766081141,
#   7.195182621860507e-06,
#   0.0012748273674076916,
#   0.0004604099310871681,
#   6.581548092266796e-05,
#   0.00038621028630847536,
#   1.0785697442405584e-05,
#   0.00028901895654730907,
#   5.337973021826415e-05,
#   3.599737717010393e-06,
#   1.8002984086623117e-06,
#   0.0005016832069098309,
#   0.0005968892038732152,
#   0.0014657894298489881,
#   1.616505159204311e-05,
#   0.00023705007041815326,
#   7.193895526899196e-06,
#   0.0005644904227243149,
#   3.599737717010393e-06,
#   0.0002713271634780586,
#   0.007562546174794416,
#   0.0008242724419085128,
#   0.0005919453789049729,
#   0.00024888520451190704,
#   0.0005656652619275762,
#   1.9737285348938317e-05,
#   0.0002678268174813864,
#   3.756384020434787e-05,
#   5.3979964108954215e-06,
#   0.0004320192178038313,
#   0.0001266274570298102,
#   8.989152966046286e-06,
#   1.800513241407788e-06,
#   4.1077810042099166e-05,
#   0.001041932346481148,
#   5.3944565829493994e-06,
#   0.0003019624197308001,
#   0.0014686038526589556,
#   7.19432452017711e-06,
#   7.195611730275204e-06,
#   3.0443211391960922e-05,
#   0.0013289446460527264,
#   5.525405328415105e-05,
#   0.0024634079850149146,
#   0.00016247603122083253,
#   1.6169869143042893e-05,
#   0.0003339826413845745,
#   8.990224921799566e-06,
#   7.195611730275204e-06,
#   0.00010959538607720117,
#   5.398962423225607e-06,
#   0.0023042944778906655,
#   0.0016354826801903094,
#   8.183435774664117e-05,
#   0.0006488214719419105,
#   0.0008052892820817998,
#   1.8001910067080343e-06,
#   0.0003247230078934894,
#   5.1658604986259744e-05,
#   7.114765192264941e-05,
#   0.0011537517757216893,
#   7.992257642217095e-05,
#   0.0002169044667831641,
#   0.010647112973420103,
#   0.00198520504530704,
#   0.0011612962423927012,
#   3.0463147116468062e-05,
#   0.0007197182527092357,
#   4.819599800145516e-05,
#   0.0002051293713548771,
#   4.821604655116403e-05,
#   0.00039348543654291835,
#   4.470822175102951e-05,
#   2.6922497083332813e-05,
#   0.0006526903394716765,
#   0.00018762177241693509,
#   0.0007534307663179167,
#   0.00040326414296003885,
#   1.8006206722012698e-06,
#   0.0008511529694746398,
#   0.001043241509863631,
#   2.3307832089781486e-05,
#   1.9766707531323975e-05,
#   3.6008116404570427e-06,
#   0.0008317394182071031,
#   4.2896933222815326e-05,
#   0.0005635271206638107,
#   0.0004793712943957964,
#   0.0005035082417707753,
#   6.075259657395403e-05,
#   0.007427077388057744,
#   0.0025364435245770786,
#   0.0021621059501410523,
#   0.47470572560467067,
#   0.0015639651765108988,
#   0.00031683398484737605,
#   0.0006802565320186069,
#   0.00047272405379452796,
#   0.0001775593172290745,
#   9.030045466086818e-05,
#   0.00015932820210888342,
#   4.6386156712846163e-05,
#   2.686965058076222e-05,
#   5.395743390132819e-06,
#   0.0025558182288002913,
#   0.0022241326729075727,
#   8.064862913555999e-05,
#   0.0001942940781891892,
#   0.0007369602605234627,
#   0.00012341549344296087,
#   0.00028059861462053834,
#   9.045559396698854e-05,
#   0.00010276150408041566,
#   1.0787626703947283e-05,
#   0.002329697453506375,
#   0.0008956642781601361,
#   1.4344135294223121e-05,
#   4.6386156712846163e-05,
#   0.00038924019061255016,
#   1.0768998833333115e-05,
#   7.248722340600513e-05,
#   0.00014573154079085518,
#   0.000215925587622497,
#   0.00012204119559025246,
#   0.0010835151483853992,
#   0.00012166678109827644,
#   0.0013495225676635263,
#   0.00043278417429088996,
#   2.510821615728015e-05,
#   0.00012596550937106783,
#   0.052531932696756836,
#   0.0001601846899487917,
#   0.008455049351836524,
#   0.0004476492977822686,
#   0.00047255221682525664,
#   4.118297310582997e-05,
#   6.977386510103494e-05,
#   0.0005013289088089801,
#   8.710937600756414e-05,
#   5.715173571074679e-05,
#   6.040742227924091e-05,
#   6.059042875542407e-05,
#   6.046116155061099e-05,
#   3.60016722872902e-06,
#   0.000710726134882377,
#   0.001266761589133868,
#   0.3183122264472998,
#   0.04033081643282134,
#   0.00020406027307624125,
#   0.00087021705072248,
#   1.25885665009844e-05,
#   0.00047191878272284047,
#   0.00010468809756398072,
#   0.00030153345144225965,
#   0.0001207169464806067,
#   0.0005374231658803743,
#   0.00016004303596823242,
#   0.00014423161328737058],
#  [1.7086984811075412e-09,
#   3.982039591501564e-07,
#   3.794521451654382e-07,
#   6.8292920184912064e-09,
#   1.250803633819956e-06,
#   4.6587963416508035e-07,
#   4.554540536446033e-08,
#   8.529745020295421e-09,
#   3.889490095913934e-08,
#   4.949638575729172e-07,
#   1.532336883411261e-08,
#   2.3778917969985647e-08,
#   5.121510795134185e-09,
#   3.4503423779961994e-07,
#   1.5343932204691206e-08,
#   7.299516728286186e-06,
#   1.3628471896350126e-07,
#   3.4173969622150647e-09,
#   7.046890258872191e-06,
#   3.086917059031471e-07,
#   5.124260927658408e-09,
#   1.7090043431816633e-09,
#   1.856177941412048e-05,
#   3.0313466174685758e-06,
#   6.388673883622879e-05,
#   4.092274201525734e-06,
#   1.7088514030203768e-09,
#   8.7226487555682e-08,
#   2.5532260782312813e-05,
#   1.7091573015940931e-09,
#   7.060904872313655e-08,
#   5.123343998085976e-09,
#   2.7285726123482383e-06,
#   1.0577229221438657e-07,
#   2.304047319226335e-06,
#   4.9941883003655945e-06,
#   5.995460114678845e-08,
#   1.8361025147071304e-07,
#   1.561349186059634e-05,
#   2.7173479253356007e-08,
#   1.7442405484000515e-07,
#   6.826237955562347e-09,
#   0.9938814699404499,
#   7.657005870828227e-05,
#   1.9869635118871354e-06,
#   1.876274574413001e-05,
#   7.160501695522607e-08,
#   3.876705675329438e-05,
#   5.0367758197326834e-08,
#   3.4161739517722624e-09,
#   3.4173969622150647e-09,
#   4.471461456617899e-07,
#   1.065377779230924e-06,
#   4.698757205470925e-06,
#   1.532473858192936e-08,
#   2.1977043954544922e-07,
#   6.824406391859888e-09,
#   4.993211395641287e-07,
#   3.4161739517722624e-09,
#   1.2655995276783475e-06,
#   1.3712722028555038e-05,
#   9.356201729049513e-06,
#   6.802912516691865e-06,
#   2.290807727262261e-07,
#   5.036789982278625e-07,
#   1.8701802841964243e-08,
#   2.4744572315087426e-07,
#   3.553808454522693e-08,
#   5.1219690138684096e-09,
#   7.470275757694187e-06,
#   1.1878846401582612e-07,
#   8.525931537138195e-09,
#   1.7090043431816633e-09,
#   2.3299518317106583e-07,
#   5.827517593498548e-05,
#   5.116931612505183e-09,
#   7.5327779100956646e-06,
#   2.417705631262248e-05,
#   2.047505052084442e-08,
#   6.8268486224433285e-09,
#   2.881774017086783e-08,
#   0.0008117386595186531,
#   5.2181198924922655e-08,
#   1.0271410508609858e-06,
#   1.519116797081281e-07,
#   1.533158977039279e-08,
#   3.0606099897755823e-07,
#   8.527456657557388e-09,
#   6.8268486224433285e-09,
#   1.0307212945269836e-07,
#   5.123343998085976e-09,
#   0.00021154346495644297,
#   8.796988734236912e-06,
#   7.72099530970331e-08,
#   5.780625758729328e-07,
#   6.94989003221568e-07,
#   1.7085455774404155e-09,
#   1.5175108711940085e-07,
#   4.8771228948321955e-08,
#   2.6848469898158887e-07,
#   9.66899536143074e-07,
#   7.534364788391784e-08,
#   2.0131037503850522e-07,
#   0.0003768497142564353,
#   5.73565818386082e-06,
#   1.9611662439658645e-06,
#   2.884605173257324e-08,
#   6.320246576844159e-07,
#   4.5549464066852216e-08,
#   1.9050965032884903e-07,
#   4.5577888490892926e-08,
#   1.0759417587511679e-06,
#   4.229215129428761e-08,
#   2.5513853960514566e-08,
#   5.832406832361783e-07,
#   1.7492893847705706e-07,
#   3.33511780609105e-05,
#   1.1047058912467977e-06,
#   1.7091573015940931e-09,
#   7.237731493437497e-07,
#   8.496471584816131e-07,
#   2.2076480192234223e-08,
#   1.874363632026247e-08,
#   3.4177028060407598e-09,
#   7.222043077088078e-07,
#   4.056789125180895e-08,
#   0.001816361562865346,
#   1.2103298563150429e-05,
#   0.00012352188559953102,
#   5.7445563665253906e-08,
#   2.6561811926399898e-06,
#   1.5442570915370083e-05,
#   8.192178222362079e-06,
#   2.541651975978356e-05,
#   1.414273279844361e-06,
#   2.909493569407966e-07,
#   2.327108965985925e-05,
#   8.598193566506371e-07,
#   1.6490934782571607e-07,
#   8.499600324062078e-08,
#   1.3421760456098217e-06,
#   5.259274580225547e-07,
#   2.5438768647813835e-08,
#   5.118762630211086e-09,
#   9.053890363281753e-07,
#   1.5836983334541121e-06,
#   7.553796063557629e-08,
#   1.826592586109016e-07,
#   6.500183558721268e-07,
#   1.1591888441903894e-07,
#   2.5963010362773385e-07,
#   8.521513640540887e-08,
#   9.675654866672965e-08,
#   1.0232032862259459e-08,
#   6.560758918695539e-07,
#   2.7506057804768023e-07,
#   1.3586739626677979e-08,
#   4.382728816854647e-08,
#   3.551135738809831e-07,
#   1.0205541584205817e-08,
#   6.817873759330892e-08,
#   1.3578111757424624e-07,
#   2.0074736142398687e-07,
#   7.0034761985426874e-06,
#   9.080139443469033e-07,
#   1.1428314119322047e-07,
#   0.0001025390157256742,
#   3.957362755506519e-07,
#   2.3785290357449714e-08,
#   1.1785822863673279e-07,
#   4.952359097898757e-06,
#   1.5033479103184996e-07,
#   2.5919474441289536e-05,
#   4.069779715783387e-07,
#   7.641209187524364e-06,
#   2.728722383425037e-07,
#   1.980508953291829e-06,
#   6.831047059107046e-06,
#   1.396680026521357e-06,
#   8.644458969825078e-07,
#   6.265235056523575e-07,
#   5.7215706767328854e-08,
#   5.703270340179215e-08,
#   1.0250356152097698e-08,
#   6.228903747219188e-07,
#   2.1273608667862904e-06,
#   1.7590103799862864e-07,
#   6.851764464156706e-05,
#   1.8982149022273493e-07,
#   0.00195100190401323,
#   1.1941643028413663e-08,
#   8.561278573261138e-07,
#   9.864353850056348e-08,
#   2.7918726308171176e-07,
#   1.1294746911020189e-07,
#   4.793634433383969e-07,
#   1.5013541979777925e-07,
#   1.3531079719428857e-07],
#  [6.011284084868305e-08,
#   1.400900831034466e-05,
#   1.334931040451119e-05,
#   2.402578036767774e-07,
#   6.286268308399201e-06,
#   1.6389871362825642e-05,
#   1.6023094386365557e-06,
#   3.000805645666132e-07,
#   1.3683414698575364e-06,
#   1.741306844074989e-05,
#   5.39083543512969e-07,
#   8.365538608995069e-07,
#   1.8017723240039388e-07,
#   1.2138471739467667e-05,
#   5.398069728579185e-07,
#   1.0272021476260634e-05,
#   9.589124952987924e-05,
#   1.202256816973655e-07,
#   3.098912690663413e-05,
#   1.085992385048329e-05,
#   1.8027398339570948e-07,
#   6.012360122471583e-08,
#   4.081327484509421e-05,
#   1.777404057219128e-05,
#   2.365859411627386e-05,
#   9.597879341319372e-06,
#   6.011822071570478e-08,
#   3.068670114826617e-06,
#   2.13866026419433e-05,
#   6.012898237581097e-08,
#   2.4840605614746117e-06,
#   1.8024172536887416e-07,
#   9.599250716478063e-06,
#   3.721120512708903e-06,
#   4.0528750783085416e-05,
#   4.392449132886807e-05,
#   2.1092319310467833e-06,
#   1.2918995301841093e-05,
#   2.197160848881587e-05,
#   9.55976172345631e-07,
#   6.136322800487869e-06,
#   2.401503602624979e-07,
#   3.716376595829891e-05,
#   1.4640064034362963e-05,
#   2.1844481099730182e-06,
#   1.2454386611862122e-05,
#   3.5987131523861385e-07,
#   9.405819646372734e-06,
#   1.7719621489089981e-06,
#   1.201826555971393e-07,
#   6.011284084868305e-08,
#   1.573081815631199e-05,
#   1.8740253355033303e-05,
#   4.132613904707076e-05,
#   5.39131731905141e-07,
#   7.731630595865931e-06,
#   2.4008592496360375e-07,
#   1.7566359733372072e-05,
#   1.201826555971393e-07,
#   2.6714642926182445e-05,
#   0.04383132176816735,
#   2.5319670169344033e-05,
#   1.8409981539703142e-05,
#   8.059172630304615e-06,
#   1.7719671313613125e-05,
#   6.579384895887254e-07,
#   8.705260488564582e-06,
#   1.2502470412155862e-06,
#   1.8019335275758323e-07,
#   1.3831995912405446e-05,
#   4.179035746209838e-06,
#   2.999464043805745e-07,
#   6.012360122471583e-08,
#   1.3661472478742669e-06,
#   3.106286269700466e-05,
#   1.8001613453576896e-07,
#   9.815065864992732e-06,
#   2.2988123264570393e-05,
#   2.401074008349859e-07,
#   2.401718438193886e-07,
#   1.0138220684712194e-06,
#   0.00012049518788292442,
#   1.8357598727624357e-06,
#   0.0063598163324859736,
#   5.344326530583534e-06,
#   5.393727600363649e-07,
#   1.0767374305618622e-05,
#   3.000000588562165e-07,
#   2.401718438193886e-07,
#   3.6261274778618805e-06,
#   1.8024172536887416e-07,
#   0.0003916948232546611,
#   4.421176113831019e-05,
#   2.716283577104744e-06,
#   2.0336521632245993e-05,
#   2.445005002589079e-05,
#   6.010746162355426e-08,
#   5.33867680546563e-06,
#   1.715795476019179e-06,
#   2.3613554642077016e-06,
#   3.401599438138435e-05,
#   2.6506260550249284e-06,
#   1.4164393156169337e-05,
#   0.00014730839581796417,
#   5.0445808810192685e-05,
#   0.0006554504017213686,
#   1.0148180829359085e-06,
#   2.2234933828231987e-05,
#   1.6024522257541383e-06,
#   6.702221847199967e-06,
#   1.6034522107704926e-06,
#   2.523476842028464e-05,
#   1.4878583834487124e-06,
#   8.975897500481397e-07,
#   0.0005540046289023813,
#   6.154084851579255e-06,
#   2.346621222009997e-05,
#   3.886408875489709e-05,
#   6.012898237581097e-08,
#   2.5462690239444676e-05,
#   5.978199779546311e-05,
#   7.766612746297377e-07,
#   6.594102116338332e-07,
#   1.2023644143140977e-07,
#   0.004014384625577764,
#   2.8543961586552088e-06,
#   1.7794619953795737e-05,
#   1.520713965953712e-05,
#   1.591780150925929e-05,
#   2.020962776202621e-06,
#   0.0008410116773524805,
#   0.91531330949039,
#   9.606826699381505e-05,
#   0.00636435433928124,
#   1.658493984901767e-05,
#   1.0235739413470003e-05,
#   0.00021544426704787887,
#   0.0005444795116843472,
#   5.801590795516999e-06,
#   2.990200595406286e-06,
#   5.2464893219884385e-06,
#   1.54186524283531e-06,
#   8.949482123500861e-07,
#   1.8008055062623961e-07,
#   0.006816333388729492,
#   5.5715275061018766e-05,
#   2.6574620718204388e-06,
#   6.426041261123182e-06,
#   0.0002744155302340057,
#   4.078082544980042e-06,
#   9.133912900059973e-06,
#   2.997909806367272e-06,
#   3.4039422843642786e-06,
#   3.599678760227015e-07,
#   0.01054804803285213,
#   9.676764470001491e-06,
#   4.779880861728145e-07,
#   1.54186524283531e-06,
#   1.2493067668719412e-05,
#   3.5903590001925557e-07,
#   2.3985610378457165e-06,
#   4.776845535501637e-06,
#   7.062389486207826e-06,
#   4.039109632228298e-06,
#   3.19443707174894e-05,
#   4.020536305377136e-06,
#   3.921056824479221e-05,
#   1.3922194005116408e-05,
#   8.367780445794768e-07,
#   4.146309614646236e-06,
#   4.3556598424046056e-05,
#   5.288850822562914e-06,
#   1.8997076566341047e-05,
#   1.4317682320728178e-05,
#   1.4934524625349066e-05,
#   1.3713968026266114e-06,
#   2.3225088339645714e-06,
#   0.0007690225499404519,
#   2.8903459039355918e-06,
#   1.9007266057381012e-06,
#   2.003763693917042e-06,
#   2.0128762991115986e-06,
#   2.0064381520020217e-06,
#   1.2020416608044592e-07,
#   0.00017530868260649598,
#   3.742079326071337e-05,
#   6.188283783968682e-06,
#   9.096165856932033e-05,
#   6.678012041084591e-06,
#   2.746586343414038e-05,
#   4.201127903932611e-07,
#   1.505949651228419e-05,
#   3.4703275014277425e-06,
#   9.82194324988932e-06,
#   3.973546714035963e-06,
#   1.686423830575416e-05,
#   5.281836845904066e-06,
#   4.7602994365491984e-06]]

# %%
greatest_prob = max(pred_prob_list[0])
greatest_prob
# Out:
# 0.12456661669529484

# %%
def get_greatest_probabilities(pred_prob_list):
    max_probabilities = []
    for i in pred_prob_list:
       max_probabilities.append(max(i))
    return max_probabilities

# %%
get_greatest_probabilities(pred_prob_list)
# Out:
# [0.12456661669529484,
#  0.47470572560467067,
#  0.9938814699404499,
#  0.91531330949039]

# %%
def prediction_script(text):
    predict_vect = vectorizer_train.transform(text)
    yield model.predict(teste_predict_vect)

# %%
list(prediction_script(['EPSON MAGENTO','LILLO BICO','BOV AMERICANA KG','KING 100ML JASMIM']))
# Out:
# [array(['ACESSORIO DE INFORMATICA', 'PRODUTO FARMACEUTICO', 'CARNE BOVINA',
#         'PRODUTO DE LIMPEZA'],
#        dtype='<U36')]

# %%
filename = 'model_v2.pkl'

# %%
from sklearn.externals import joblib

# %%
with open(filename, 'wb') as file:
	joblib.dump(model, file)

# %%
file.close()

# %%
vocab_filename = 'model_v2_vocabulary.pkl'

# %%
with open(vocab_filename, 'wb') as file2:
    joblib.dump(vectorizer_train.vocabulary_, vocab_filename)

# %%
vectorizer_train.vocabulary_
# Out:
# {'esponja': 17922,
#  'apetivan': 11004,
#  '5030': 6489,
#  '26623': 4363,
#  'selecao': 29859,
#  'sleek': 30279,
#  '49pol': 6253,
#  'alben': 10309,
#  'brome': 12878,
#  'dubom': 17130,
#  'repouso': 28807,
#  'aplause': 11014,
#  '9761': 9678,
#  'esquerda': 17943,
#  'residuo': 28839,
#  'sdsdqm16gbb35a': 29760,
#  'helice': 20505,
#  '1x830g': 3262,
#  'lorasliv': 22811,
#  '18mmx5m': 2814,
#  '12x800g': 1996,
#  'susporal': 30976,
#  'endivia': 17584,
#  'ambar': 10617,
#  'petite': 26606,
#  'biovagin': 12331,
#  'maxmallows': 23596,
#  'cleosol': 14607,
#  'querat': 28013,
#  'r616': 28299,
#  'fundo': 19434,
#  'depilador': 16318,
#  '08mts': 661,
#  'delitos': 16255,
#  'gfao': 19803,
#  'buscofem': 13016,
#  'artificial': 11237,
#  'cuscuz': 15796,
#  '12an': 1737,
#  'unique': 32322,
#  'guarana': 20298,
#  '9141': 9530,
#  '5x7': 7124,
#  'permetrina': 26542,
#  'ciloxan': 14407,
#  'abelha': 9820,
#  '5x30': 7108,
#  'q612': 27919,
#  'ovulos6': 25800,
#  'cx10': 15870,
#  'hz': 20906,
#  'pardal': 26135,
#  '1943': 2877,
#  'rosalina': 29204,
#  '4x14': 6361,
#  '1490': 2194,
#  'cx100': 15871,
#  'berlison': 12109,
#  'zaratustra': 33408,
#  'spr35ml': 30595,
#  'cpd30gnmed': 15450,
#  'quilmes': 28032,
#  'megaimpact': 23708,
#  'vigotas': 32783,
#  '19x10m': 2906,
#  '11214100197': 1440,
#  'freegells': 19248,
#  '21333': 3698,
#  '215': 3704,
#  'watr': 33056,
#  'caps1': 13567,
#  '2bltx7': 4591,
#  '4gr': 6304,
#  '500w': 6463,
#  'baileys': 11704,
#  'px': 27899,
#  'caprice': 13561,
#  'pqc': 27305,
#  '2cm': 4607,
#  '20x270g': 3598,
#  'ingleza': 21155,
#  'load': 22759,
#  '00x5': 275,
#  '001345987923': 177,
#  '7899334342176': 8640,
#  'ultrax': 32248,
#  '036': 440,
#  'fps60spr150ml': 19176,
#  'conthen': 15152,
#  '7899726911089': 8845,
#  '12x1l': 1859,
#  '12x300': 1912,
#  'fast': 18389,
#  '9f': 9734,
#  '11101799304': 1328,
#  'bidog': 12238,
#  'schincar': 29718,
#  'cda': 13908,
#  'm9': 23074,
#  'cpcomp': 15407,
#  'tambau': 31155,
#  'brilu': 12837,
#  'cp24': 15396,
#  'matrix': 23549,
#  '13523240': 2068,
#  'etnil': 18047,
#  'dakota': 16045,
#  '365': 5350,
#  'hidroponico': 20689,
#  'dp': 17014,
#  'emp': 17517,
#  'impressora': 21048,
#  'pseudoefedrin': 27739,
#  'bb20l': 11908,
#  '20saches': 3533,
#  'antqueda': 10963,
#  'ilpisa': 20995,
#  '46756937': 6092,
#  '500mm': 6455,
#  'shave': 30055,
#  'tot': 31781,
#  '116': 1525,
#  '4381': 5935,
#  'dante': 16087,
#  'polidor': 27082,
#  '1188': 1555,
#  'dry12x48g': 17096,
#  'sete': 30012,
#  'ibuprofeno': 20934,
#  'eva': 18091,
#  'naps': 24762,
#  'pr': 27307,
#  'siriguela': 30230,
#  'fluid': 18928,
#  'maped': 23330,
#  'gary': 19621,
#  'medic': 23669,
#  'necessarias': 24903,
#  'enxutinha': 17682,
#  'starfer': 30667,
#  '5cv': 6986,
#  'cd': 13904,
#  '50x70cm': 6670,
#  '2313p': 3874,
#  'ultraplast': 32241,
#  '30x0': 4941,
#  '12rfx12ptx14g': 1798,
#  'claritromicina': 14566,
#  'rmp007401': 29090,
#  '30vl': 4937,
#  '24x200gr': 4040,
#  'bactroban': 11682,
#  'depilacao': 16317,
#  '1frx45ml': 2979,
#  'genialflex': 19723,
#  'crech': 15558,
#  'magro': 23191,
#  'blx28': 12490,
#  'reequilib': 28615,
#  '220w': 3785,
#  'recompensa': 28565,
#  '20x120g': 3567,
#  '210x140x18': 3682,
#  'fostair': 19139,
#  'f5': 18263,
#  '187': 2774,
#  'individual': 21103,
#  '30x10': 4946,
#  'adstring': 10134,
#  'multipla': 24599,
#  '82900': 9177,
#  'encerad': 17575,
#  '133mgxpecer120mlgnnq': 2057,
#  '7tab': 9041,
#  '035mg21drg': 439,
#  'bordom': 12649,
#  '7891306113876': 8326,
#  'sn': 30323,
#  'mvergine': 24655,
#  'delco': 16226,
#  'folinato': 19022,
#  'bongo': 12611,
#  'hsb50': 20837,
#  'rolamento': 29150,
#  'prosso': 27667,
#  'taked': 31125,
#  'cantoneira': 13509,
#  'ae': 10164,
#  'dcf04': 16127,
#  'alcance': 10323,
#  'nio': 25110,
#  'gnmel': 19992,
#  'bdja': 11945,
#  'parodontax': 26160,
#  'karina': 21755,
#  'econã': 17302,
#  'unizinco': 32334,
#  '7899726951849': 8954,
#  'cibrato': 14346,
#  'dietilamo': 16653,
#  'xar': 33247,
#  'vã': 33028,
#  '20cp': 3473,
#  'vitacin': 32864,
#  'magnet': 23179,
#  'acb002e': 9871,
#  'minuano': 24099,
#  'pantanal': 26050,
#  '20x30': 3604,
#  'r064': 28066,
#  'interlagos': 21264,
#  'dust': 17209,
#  '1x26': 3142,
#  '10045410': 792,
#  '430': 5914,
#  'bloom': 12463,
#  'tolue': 31683,
#  'lugar': 22944,
#  '200mg': 3358,
#  '156': 2368,
#  '0000000864': 51,
#  'cardbet': 13648,
#  '6x200ml': 7674,
#  '77714435': 8094,
#  'cabac32': 13181,
#  'revestidos': 28939,
#  'cobrete': 14769,
#  'fashion': 18387,
#  'capricci': 13560,
#  '30s': 4922,
#  'gramp': 20131,
#  'hipopo': 20746,
#  'alcachofra': 10319,
#  '122x244': 1659,
#  'cedula': 13949,
#  'pantopra': 26061,
#  'gazes': 19649,
#  'prolongada': 27613,
#  '24x600ml': 4120,
#  '6x5kg': 7743,
#  'betsona': 12164,
#  'pozzani': 27286,
#  'confeitos': 15096,
#  'perrier': 26557,
#  '168': 2586,
#  '4x355': 6383,
#  'jimador': 21615,
#  '6n': 7608,
#  'pelos': 26411,
#  'cfermento': 14117,
#  'fenix': 18547,
#  'ursin': 32374,
#  'guzman': 20328,
#  'naratriptana': 24766,
#  'trap': 31904,
#  '180mg': 2746,
#  'deobeaute': 16306,
#  '360w': 5341,
#  '42und': 5907,
#  '500g': 6435,
#  '536': 6776,
#  'artic': 11231,
#  '7898409951763': 8586,
#  'kobber': 21914,
#  'ap2710': 10980,
#  'panazzo': 26026,
#  '7899334369890': 8680,
#  'sabor': 29395,
#  '77l': 8104,
#  'proteinas': 27687,
#  'distrel': 16795,
#  'lundbeck': 22978,
#  'permitrina': 26543,
#  'aginina': 10227,
#  'pc3': 26287,
#  'pulmovic': 27827,
#  'inalacao': 21062,
#  'espada': 17867,
#  'amato': 10609,
#  'gelatinosas': 19690,
#  '7apl': 9000,
#  'tpa': 31816,
#  '75x40': 8027,
#  '041': 472,
#  '4mgml': 6315,
#  '1621': 2539,
#  '6806': 7521,
#  '165': 2562,
#  'sperf': 30555,
#  '00mx06mm': 268,
#  'bonobon': 12620,
#  '42p': 5904,
#  'betina': 12157,
#  'kalonat': 21735,
#  'caboemborrac1254': 13210,
#  'lvula': 23032,
#  'irresi': 21372,
#  'comport': 15000,
#  'rd': 28496,
#  'h0691300': 20352,
#  '7891019205585': 8238,
#  '7896058507218': 8536,
#  '431171': 5919,
#  '19mmx2m': 2900,
#  'alu': 10524,
#  'pateta': 26229,
#  'funghi': 19436,
#  'bio': 12276,
#  'cza': 15983,
#  'ninf': 25106,
#  '638': 7381,
#  'predcort': 27376,
#  'agatek': 10214,
#  'decor': 16168,
#  'pull': 27821,
#  '27mg15cm2': 4436,
#  'visao': 32844,
#  '0250ml': 387,
#  'doriless': 16960,
#  'cc640wl': 13877,
#  'isqueiros': 21435,
#  'pintadinha': 26818,
#  'envelopes': 17670,
#  'nolvadex': 25183,
#  'varfarina': 32505,
#  'eti': 18025,
#  'litoragua': 22693,
#  'farmasa': 18373,
#  '5kg': 7007,
#  'harald': 20410,
#  'usafe': 32385,
#  'depakene': 16311,
#  'gabaneurin': 19535,
#  '24x90ml': 4133,
#  'aquamix': 11068,
#  '6x475ml': 7731,
#  '7891019201730': 8230,
#  'atuais': 11431,
#  'extrafr': 18207,
#  'perini': 26523,
#  '2bltx10comp': 4584,
#  'magenta': 23158,
#  'caps60': 13587,
#  'xt1635': 33315,
#  'bac': 11648,
#  'luminosos': 22970,
#  'miclox': 23939,
#  '500mf': 6444,
#  'mosquit': 24435,
#  'bx': 13048,
#  'cod': 14786,
#  '50': 6408,
#  '72x100g': 7935,
#  'bodysense': 12528,
#  '7899726918118': 8883,
#  'deteclean': 16508,
#  'pesqueira': 26579,
#  'tamoxifeno': 31159,
#  'po': 27022,
#  'mod1': 24252,
#  '50214': 6478,
#  'festa': 18605,
#  'emergencia': 17504,
#  '528': 6746,
#  'cha31cb': 14140,
#  'insana': 21189,
#  'western': 33097,
#  'oxid': 25817,
#  '1x105': 3055,
#  'kalipto': 21733,
#  'hydra': 20879,
#  'safira': 29445,
#  '7040': 7813,
#  'edu': 17328,
#  'rcd34': 28490,
#  'solvelusa': 30430,
#  'acrilmix': 10006,
#  'gestodeno': 19793,
#  'without': 33156,
#  'gigant': 19823,
#  '30x40g': 4999,
#  '20x100fl': 3552,
#  'guaiuba': 20291,
#  '9288': 9561,
#  '56tab': 6899,
#  'autoclave': 11464,
#  'serie': 29974,
#  '0000000439': 37,
#  'revange': 28929,
#  '38x58': 5471,
#  'dorene': 16951,
#  'ferrug': 18598,
#  'kim': 21864,
#  '6qe': 7623,
#  'keftron': 21792,
#  'pinos': 26811,
#  'acendedor': 9901,
#  'marchand': 23369,
#  'garganta': 19602,
#  'stages': 30653,
#  'camisete': 13407,
#  'capela': 13532,
#  'capp': 13554,
#  'tto': 32104,
#  'unigyn': 32312,
#  'lipistatina': 22637,
#  'life': 22519,
#  '32x200gr': 5170,
#  '7891306073606': 8306,
#  'novita': 25285,
#  'ctea': 15724,
#  'kouro': 21934,
#  '18x400g': 2847,
#  'remicade': 28733,
#  'samito': 29517,
#  '406216': 5705,
#  '450w': 6014,
#  'mbset': 23623,
#  'fmh90': 18970,
#  'regent': 28679,
#  'diaf': 16592,
#  'eudora': 18069,
#  'oggi': 25500,
#  'ingelheim': 21151,
#  'clotrimix': 14707,
#  'cpd5': 15466,
#  'gerenciamento': 19758,
#  'anv': 10970,
#  'mometasona': 24313,
#  '24x500g': 4109,
#  '15a': 2388,
#  '12': 1587,
#  'placentina': 26910,
#  'surround': 30963,
#  'capil': 13539,
#  '30701239895': 4835,
#  '40mgg': 5751,
#  'rh0980700': 28973,
#  'ansitec': 10859,
#  '1020g': 970,
#  'interf': 21258,
#  '409': 5714,
#  'cote': 15340,
#  'novo': 25287,
#  'maxixi': 23593,
#  'zelnin': 33431,
#  'gl': 19874,
#  'nx': 25400,
#  'fci': 18450,
#  '1x45': 3194,
#  'regular': 28690,
#  'fiasini': 18634,
#  'egc35': 17371,
#  'resodic': 28853,
#  '7899397802068': 8690,
#  '30201': 4795,
#  'patchouli': 26225,
#  'alaplast': 10301,
#  '700va': 7789,
#  '24comp': 3967,
#  'n25': 24696,
#  'n155': 24690,
#  'gff': 19804,
#  'jg': 21607,
#  '26x36': 4384,
#  '8700': 9273,
#  'pto': 27805,
#  'echelon': 17282,
#  'semideuses': 29895,
#  'sadilar': 29436,
#  'zoom': 33489,
#  'donepezila': 16937,
#  'r1220': 28100,
#  'yanagi': 33350,
#  'cansado': 13500,
#  'muda': 24553,
#  '7898409951329': 8582,
#  'corpete': 15267,
#  '1mgml': 3007,
#  'ag68': 10208,
#  'trdl': 31936,
#  'truffon': 32083,
#  '30x30': 4982,
#  '11101799105': 1323,
#  '41001': 5816,
#  'sola': 30388,
#  'rej': 28702,
#  '40x17g': 5778,
#  '2x5kg': 4720,
#  'hidratacao': 20639,
#  's50': 29364,
#  'fracionavel': 19193,
#  '11lpcz': 1575,
#  'mort': 24412,
#  'concava': 15035,
#  'mgraostomate': 23921,
#  'bacias': 11657,
#  '4env': 6295,
#  'dâ': 17240,
#  '7896058503777': 8530,
#  '14198': 2149,
#  'sort': 30476,
#  'enlat': 17624,
#  'canadense': 13442,
#  'etilefrina': 18029,
#  'naturol': 24843,
#  'montana': 24358,
#  'escureto': 17800,
#  'peugeot': 26619,
#  '9und': 9751,
#  'pratti': 27350,
#  'bagageiro': 11691,
#  'natan': 24797,
#  'cortante': 15302,
#  '6x5ml': 7744,
#  'anti': 10875,
#  'bergamo': 12104,
#  '50x15g': 6632,
#  'anasol': 10761,
#  'n8': 24713,
#  'cpd60gnt': 15472,
#  'cremercare': 15574,
#  'leg': 22349,
#  'chuquinha': 14322,
#  'ntg': 25319,
#  'bosch': 12665,
#  'off': 25474,
#  '2x25ml': 4704,
#  '50x4ml': 6657,
#  'mob': 24237,
#  '01a': 346,
#  'blx30': 12492,
#  '12x100g': 1817,
#  'bright': 12818,
#  'cong': 15109,
#  '93': 9572,
#  'destadin': 16495,
#  'er': 17724,
#  'xsara': 33309,
#  'tra': 31830,
#  'linguica': 22608,
#  'ctc': 15723,
#  '7896072648720': 8549,
#  '1001': 767,
#  '2bx15comp': 4602,
#  't03': 31035,
#  'spraydose200': 30600,
#  'c2sx': 13115,
#  '10x400gr': 1249,
#  'fertnon': 18601,
#  '440mg': 5952,
#  'cruzer': 15699,
#  '254': 4183,
#  'lista': 22680,
#  'garoto': 19609,
#  'dende': 16286,
#  '290': 4534,
#  'dn50': 16854,
#  'pitiulinha': 26890,
#  'compact': 14972,
#  'tylidol': 32189,
#  '30674': 4831,
#  'caicara': 13285,
#  'redfox': 28589,
#  'manequim': 23292,
#  'sereias': 29966,
#  'cp10': 15386,
#  'forca': 19041,
#  '10x10cp': 1216,
#  'engate': 17613,
#  'frno': 19331,
#  'soquete': 30464,
#  '00x0': 271,
#  '4c74': 6277,
#  'fuyu': 19481,
#  '11108': 1398,
#  'dstar': 17108,
#  'sopao': 30456,
#  '55uj6585': 6869,
#  'noctiden': 25169,
#  '0124f': 314,
#  'esg1': 17833,
#  'st200': 30642,
#  'tomada': 31687,
#  'l36': 22035,
#  '87x125': 9284,
#  'raizes': 28409,
#  'phy': 26702,
#  'dc': 16123,
#  '7898409950902': 8578,
#  'efi': 17361,
#  'stopa': 30725,
#  'lipidium': 22633,
#  '24x280g': 4063,
#  '5803': 6935,
#  'behringer': 11983,
#  'moisturize': 24285,
#  'funtyl': 19445,
#  'esd': 17806,
#  'amoxi': 10704,
#  '80409': 9092,
#  'montada': 24355,
#  'ginkomed': 19846,
#  'cjt': 14521,
#  'karter': 21763,
#  'marshmallow': 23464,
#  'npal': 25307,
#  'melhoral': 23737,
#  'melã': 23755,
#  'plaf': 26911,
#  'lasilactona': 22241,
#  'afrin': 10203,
#  'branq110g': 12745,
#  'import': 21041,
#  '25x6': 4316,
#  '395': 5486,
#  'comunista': 15028,
#  'nb': 24863,
#  'farmaceut': 18365,
#  'esferog': 17815,
#  'calceos': 13321,
#  'pipet': 26842,
#  'polyfruty': 27144,
#  'amaciante': 10567,
#  'gcp': 19658,
#  'protec': 27674,
#  'crak': 15532,
#  'persuasao': 26565,
#  'normaten': 25229,
#  'torque': 31751,
#  'farmo': 18376,
#  'moriatico': 24404,
#  'pschorr': 27736,
#  'r62006': 28306,
#  'tinida': 31587,
#  '30366': 4809,
#  'umidi': 32267,
#  'cadence': 13254,
#  'cr2032': 15514,
#  'itraspor': 21468,
#  'alegro': 10355,
#  'gostosinha': 20064,
#  '0104001829': 293,
#  'radifree': 28392,
#  'billion': 12263,
#  'dunia': 17162,
#  'wmi': 33158,
#  'sorve': 30486,
#  'fondue': 19029,
#  'retangular': 28891,
#  'profi': 27578,
#  'cavalete': 13850,
#  'bikini': 12258,
#  'forinset': 19047,
#  'vario': 32515,
#  'en': 17554,
#  '90x126g': 9515,
#  'bps': 12713,
#  'docat': 16873,
#  '310lt': 5029,
#  'toda': 31667,
#  'tentadora': 31384,
#  'san': 29524,
#  '10sup': 1188,
#  'blusa': 12480,
#  'grav': 20176,
#  'agachamber': 10210,
#  'windy': 33143,
#  'ev': 18088,
#  'baguete': 11694,
#  'tropi': 32072,
#  'prolev': 27606,
#  'ferramenta': 18583,
#  'xtandi': 33318,
#  'chester': 14225,
#  'caladryl': 13311,
#  '237ml': 3889,
#  '7899726931988': 8922,
#  '930': 9573,
#  'smack': 30299,
#  'duspatalin': 17208,
#  'k100': 21699,
#  'happydent': 20409,
#  'crepom': 15596,
#  'gesso': 19785,
#  'acido': 9949,
#  '120cm': 1615,
#  '4pts': 6333,
#  '20x18': 3573,
#  '2ml': 4650,
#  '2650': 4356,
#  'happy': 20408,
#  '30undx30gr': 4934,
#  '16mg': 2613,
#  'paredex': 26139,
#  'guajara': 20292,
#  'norbras': 25196,
#  '12x130g': 1834,
#  'ref748': 28624,
#  '7891306172033': 8395,
#  'pomp': 27164,
#  '297x420': 4560,
#  'fd24': 18465,
#  '42ml': 5903,
#  'melagriao': 23725,
#  'cg125': 14125,
#  'bold': 12549,
#  'cremderm': 15566,
#  'inf': 21118,
#  '7899558824243': 8721,
#  'ultimo': 32229,
#  'dart': 16103,
#  'bonec': 12606,
#  '14mm': 2221,
#  'higroton': 20718,
#  'litoral': 22694,
#  'catalogo': 13827,
#  '382212': 5447,
#  'hidrofilo': 20678,
#  '585836': 6944,
#  'confianca': 15099,
#  '3268': 5118,
#  'b30': 11628,
#  'mirena': 24129,
#  '3052': 4819,
#  'moran': 24380,
#  'brinde': 12848,
#  'jmd': 21625,
#  '84t': 9227,
#  'pt11': 27777,
#  'pinha': 26802,
#  '7bl': 9004,
#  'd1': 15990,
#  'cphd': 15483,
#  'cicley': 14358,
#  'amber': 10618,
#  'kaloba': 21734,
#  'sorgo': 30469,
#  '153g': 2336,
#  '30com': 4867,
#  'artpop': 11243,
#  '6x450': 7725,
#  '12x30ml': 1917,
#  'dour': 16994,
#  'jf1000': 21605,
#  'snickers': 30331,
#  'auto': 11463,
#  '32d400': 5131,
#  '31430': 5047,
#  'milagre': 24005,
#  'daronx': 16101,
#  '7899726909932': 8829,
#  '7891306159768': 8373,
#  'cabos': 13211,
#  '428926': 5889,
#  'condimentado': 15074,
#  'tingida': 31583,
#  'ronmontilla': 29190,
#  'terranoble': 31427,
#  'clip': 14636,
#  'cortad': 15297,
#  'toner': 31701,
#  'bau': 11879,
#  '590ml': 6952,
#  'terranova': 31428,
#  '243122': 3942,
#  '40cmp': 5726,
#  'diant': 16612,
#  'p3180': 25872,
#  '7898409950728': 8576,
#  '1105': 1297,
#  'raid': 28400,
#  'fd12x500ml': 18460,
#  'parmegiana': 26157,
#  'aromasin': 11183,
#  'cascara': 13773,
#  'venda': 32617,
#  '400gx12': 5654,
#  'expressao': 18180,
#  'epativan': 17692,
#  'tabl': 31087,
#  'bolonha': 12570,
#  'model': 24258,
#  '75mgml': 8012,
#  'ptatrc6en': 27797,
#  '2bltx15c': 4587,
#  'embrulhada': 17496,
#  'bock': 12525,
#  '3777': 5424,
#  '17x17x17': 2728,
#  'antifrizz': 10917,
#  'umidiliz': 32273,
#  'dekopon': 16222,
#  'florestal': 18897,
#  'palido': 25982,
#  'duplanatex': 17180,
#  'arla': 11163,
#  'cosartan': 15321,
#  '7121838100': 7884,
#  '40ml': 5754,
#  '96g': 9665,
#  'estreia': 17995,
#  'r3914': 28234,
#  'mn4y2bz': 24220,
#  'rh1261100': 28974,
#  'tome': 31694,
#  'etica': 18026,
#  'crb36': 15541,
#  'zanotti': 33404,
#  'referencia': 28628,
#  'jerry': 21599,
#  'rapp': 28441,
#  '1x20un': 3121,
#  'isento': 21391,
#  'geriatric': 19767,
#  'cxl': 15949,
#  '200mgx15': 3360,
#  'copagril': 15197,
#  'memã': 23763,
#  '7899558824250': 8722,
#  'primavera': 27496,
#  'oleosidade': 25529,
#  'qb': 27921,
#  'confete': 15098,
#  '59': 6951,
#  '40mg25mg': 5749,
#  'cartamo': 13732,
#  'ata18': 11345,
#  's7': 29372,
#  'mackflex': 23118,
#  'gr400': 20104,
#  'xt1626': 33314,
#  '88mg': 9305,
#  'petribu': 26610,
#  'perfei': 26493,
#  'lv450': 23020,
#  'taiff': 31119,
#  '28x160g': 4522,
#  'aperol': 11001,
#  '05k': 550,
#  '150x54': 2312,
#  'sanilar': 29561,
#  '9892': 9703,
#  'seek': 29831,
#  '10x': 1202,
#  '20050mg': 3322,
#  '24x250ml': 4057,
#  '50x8': 6672,
#  'caseira': 13778,
#  'nutritive': 25386,
#  'marinh': 23419,
#  'faces': 18289,
#  'pa110': 25909,
#  'diidratada': 16679,
#  'intestin': 21275,
#  'fum': 19422,
#  'triaxon': 31971,
#  '1x72': 3251,
#  'thioctacid': 31516,
#  '8om': 9365,
#  'aro26': 11180,
#  'aladdin': 10296,
#  '2588wheato': 4206,
#  'toddy': 31671,
#  'amanteigado': 10584,
#  'adega': 10066,
#  'orlistate': 25684,
#  'galego': 19557,
#  'vit': 32860,
#  '9295301277': 9565,
#  '45x35cm': 6065,
#  'bicho': 12226,
#  'esi': 17839,
#  'lioresal': 22626,
#  'rop060011': 29192,
#  'galaxy': 19553,
#  'empadao': 17522,
#  '3540': 5296,
#  'respiramax': 28863,
#  '95gr': 9635,
#  'color': 14885,
#  'bros': 12911,
#  'rosucor': 29232,
#  'kerium': 21821,
#  'microvlar': 23984,
#  'h0002243782': 20349,
#  '12x500g': 1957,
#  'blistz': 12454,
#  '50lts': 6578,
#  'frx60ml': 19391,
#  'girl': 19863,
#  '1x64g': 3240,
#  'lubrifi': 22926,
#  'diff': 16657,
#  'malzbier': 23258,
#  'mkmen': 24178,
#  '1486': 2189,
#  'mantega': 23318,
#  'ictus': 20957,
#  '760mm': 8037,
#  'morg': 24400,
#  'adjust': 10100,
#  '2800': 4456,
#  '92104': 9549,
#  '38': 5436,
#  'farmac': 18363,
#  'yur': 33393,
#  '20x80g': 3639,
#  'sct': 29749,
#  'covizzi': 15370,
#  'maita': 23206,
#  'origine': 25681,
#  'aceclof': 9893,
#  '30x200g': 4977,
#  '7891306062068': 8288,
#  'natuhair': 24820,
#  '10v40': 1196,
#  'vim': 32792,
#  '04242': 476,
#  'inmetro': 21176,
#  'maximum': 23585,
#  'bailarina': 11703,
#  'curto': 15792,
#  'artpel': 11242,
#  '1x240g': 3131,
#  'vitamil': 32889,
#  '5mmx4m': 7042,
#  'bgaf': 12195,
#  'mg9n2bz': 23918,
#  'snif': 30332,
#  '30x25gr': 4979,
#  '1revgn': 3026,
#  'desam': 16373,
#  'arabia': 11087,
#  '21908': 3720,
#  'blts': 12471,
#  '25x8': 4319,
#  'cetoprofeno': 14097,
#  'glaucotrat': 19888,
#  'pb2': 26262,
#  '41874600': 5861,
#  'pink': 26808,
#  'baun': 11886,
#  'biscuit': 12354,
#  'amarela': 10591,
#  'forrageiro': 19085,
#  'r13193': 28108,
#  'celia': 13983,
#  'gnmer': 19993,
#  '20v': 3540,
#  'adore': 10114,
#  '21cpd': 3732,
#  'env': 17654,
#  'escuro': 17803,
#  'profuse': 27591,
#  'azul12x90g': 11596,
#  'parã': 26168,
#  'dolce': 16903,
#  'acetona': 9927,
#  '3mt': 5560,
#  '1x30': 3154,
#  '11104182005': 1374,
#  '04b': 496,
#  '81l': 9153,
#  '1159': 1518,
#  'pulg': 27818,
#  'crios': 15625,
#  '1970': 2884,
#  '150x1050x1250mm': 2305,
#  'distribuidor': 16797,
#  'tramon': 31865,
#  'pc5': 26290,
#  'autonomia': 11480,
#  'pencivet': 26418,
#  'gsb': 20254,
#  'gr360': 20102,
#  'yo': 33372,
#  'profmedextmc36': 27585,
#  'manicure': 23302,
#  'nutratopic': 25350,
#  'iwp': 21484,
#  '960g': 9646,
#  'cicatricure': 14351,
#  'mineralmk': 24062,
#  'parfum': 26142,
#  '55r18': 6867,
#  'metsil': 23894,
#  '221': 3792,
#  'anilha': 10827,
#  'parma': 26154,
#  '2027': 3402,
#  'freeze': 19252,
#  'kimono': 21867,
#  'apont': 11032,
#  'pilha': 26759,
#  '45cm': 6038,
#  'cloro': 14690,
#  '20090': 3329,
#  '210': 3645,
#  '12x40': 1939,
#  ...}

# %% [markdown]
# ### Criando um modelo para cada classe:

# %%
def train_a_model_for_each_class(df):
    for i in df.CLASSE.unique():
        
        str = i.replace(" ", "_")
        filename = "model"+str+".pkl"
        print(filename)
        
        y = []
        X = []
        
        for j in range(df.shape[0]):
            if(df.iloc[j,0]==i):
                y.append(df.iloc)
                print('ok')

# %%
train_a_model_for_each_class(df)
# Out:
# modelADUBO.pkl
# modelFERTILIZANTE.pkl
# modelACESSORIO_PARA_ARMA.pkl
# modelALBUM.pkl
# modelCARTOES.pkl
# modelEMBALAGEM_PARA_PRESENTE.pkl
# modelFAIXAS.pkl
# modelFOLHETO.pkl
# modelJORNAL.pkl
# modelLIVRO.pkl
# modelMATERIAL_PARA_ESCRITORIO_E_ESCOLAR.pkl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-397b8eedf602> in <module>()
# ----> 1 train_a_model_for_each_class(df)
#
# <ipython-input-116-9d09b523e8e9> in train_a_model_for_each_class(df)
#      10
#      11         for j in range(df.shape[0]):
# ---> 12             if(df.iloc[j,0]==i):
#      13                 y.append(df.iloc)
#      14                 print('ok')
#
# ~\Anaconda3\envs\TensorFlow\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1317     def __getitem__(self, key):
#    1318         if type(key) is tuple:
# -> 1319             key = tuple(com._apply_if_callable(x, self.obj) for x in key)
#    1320             try:
#    1321                 if self._is_scalar_access(key):
#
# ~\Anaconda3\envs\TensorFlow\lib\site-packages\pandas\core\indexing.py in <genexpr>(.0)
#    1317     def __getitem__(self, key):
#    1318         if type(key) is tuple:
# -> 1319             key = tuple(com._apply_if_callable(x, self.obj) for x in key)
#    1320             try:
#    1321                 if self._is_scalar_access(key):
#
# KeyboardInterrupt:

# %%
print(df.iloc[2, :])
# Out:
# CLASSE           ADUBOS E FERTILIZANTES
# GENERO                     FERTILIZANTE
# PRODUTO    FERTIL 06-24-12 50KG YARA SC
# Name: 2, dtype: object

# %%
df.shape[0]
